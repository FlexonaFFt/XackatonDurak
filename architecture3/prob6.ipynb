# %%
# !pip install torch numpy datasets
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Collecting datasets
#   Downloading datasets-3.5.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting fsspec (from torch)
#   Downloading fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.15)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.30.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.3.2)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2025.1.31)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 58.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 53.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 32.3 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.2 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.9 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.2 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 80.3 MB/s eta 0:00:00
# Downloading datasets-3.5.0-py3-none-any.whl (491 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.2/491.2 kB 30.0 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.2 MB/s eta 0:00:00
# Downloading fsspec-2024.12.0-py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 14.4 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 12.1 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 14.8 MB/s eta 0:00:00
# Installing collected packages: xxhash, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, fsspec, dill, nvidia-cusparse-cu12, nvidia-cudnn-cu12, multiprocess, nvidia-cusolver-cu12, datasets
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2024.12.0 which is incompatible.
# Successfully installed datasets-3.5.0 dill-0.3.8 fsspec-2024.12.0 multiprocess-0.70.16 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 xxhash-3.5.0

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from datasets import load_dataset
from collections import defaultdict
import json
import time
import os

# Модель нейросети
class DurakNet(nn.Module):
    def __init__(self, input_dim=128, hidden_dim=256, num_cards=24, num_actions=4):
        super(DurakNet, self).__init__()

        self.state_encoder = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim // 2),
            nn.ReLU()
        )

        self.action_head = nn.Linear(hidden_dim // 2, num_actions)
        self.card_head = nn.Linear(hidden_dim // 2, num_cards)
        self.state_head = nn.Linear(hidden_dim // 2, 3)

    def forward(self, state):
        encoded = self.state_encoder(state)
        action_logits = self.action_head(encoded)
        card_logits = self.card_head(encoded)
        state_logits = self.state_head(encoded)
        return action_logits, card_logits, state_logits

# Кодирование состояния
def encode_state(snapshot, my_id, device='cpu'):
    try:
        data = json.loads(snapshot['snapshot'])

        state = np.zeros(128, dtype=np.float32)

        trump = data['trump']
        suits = {'S': 0, 'C': 1, 'D': 2, 'H': 3}
        ranks = {'9': 0, '10': 1, '11': 2, '12': 3, '13': 4, '14': 5}
        trump_rank, trump_suit = trump[:-1], trump[-1]
        state[0 + suits[trump_suit]] = 1.0
        state[4 + ranks[trump_rank]] = 1.0

        for player in data['players']:
            if player['id'] == my_id:
                for card in player['hand']:
                    rank, suit = card[:-1], card[-1]
                    card_idx = ranks[rank] * 4 + suits[suit]
                    state[10 + card_idx] = 1.0

        for i, pair in enumerate(data['table'][:4]):
            attack_card = pair['attack_card']['card']
            rank, suit = attack_card[:-1], attack_card[-1]
            state[34 + i * 12 + ranks[rank]] = 1.0
            state[34 + i * 12 + 6 + suits[suit]] = 1.0
            if 'defend_card' in pair:
                defend_card = pair['defend_card']['card']
                rank, suit = defend_card[:-1], defend_card[-1]
                state[82 + i * 12 + ranks[rank]] = 1.0
                state[82 + i * 12 + 6 + suits[suit]] = 1.0

        state[114] = len(data['deck']) / 24.0

        for player in data['players']:
            if player['id'] == my_id:
                state_map = {'attack': 115, 'defend': 116, 'bat': 117, 'pass': 118, 'take': 119}
                if player['state'] in state_map:
                    state[state_map[player['state']]] = 1.0

        state[120] = data['game_rules']['game_type']

        tensor = torch.from_numpy(state).float().to(device)
        tensor.requires_grad_(True)
        return tensor

    except Exception as e:
        print(f"Error in encode_state: {e}")
        return torch.zeros(128, dtype=torch.float32).to(device)

# Проверка, может ли defend_card побить attack_card
def can_beat(attack_card, defend_card, trump_suit):
    suits = {'S': 0, 'C': 1, 'D': 2, 'H': 3}
    ranks = {'9': 0, '10': 1, '11': 2, '12': 3, '13': 4, '14': 5}

    attack_rank, attack_suit = attack_card[:-1], attack_card[-1]
    defend_rank, defend_suit = defend_card[:-1], defend_card[-1]

    attack_rank_idx = ranks[attack_rank]
    defend_rank_idx = ranks[defend_rank]
    attack_suit_idx = suits[attack_suit]
    defend_suit_idx = suits[defend_suit]
    trump_suit_idx = suits[trump_suit]

    if attack_suit_idx == defend_suit_idx:
        return defend_rank_idx > attack_rank_idx
    elif defend_suit_idx == trump_suit_idx and attack_suit_idx != trump_suit_idx:
        return True
    return False

# Извлечение действия
def get_action(prev_snapshot, curr_snapshot, my_id):
    try:
        prev_data = json.loads(prev_snapshot['snapshot'])
        curr_data = json.loads(curr_snapshot['snapshot'])

        ranks = {'9': 0, '10': 1, '11': 2, '12': 3, '13': 4, '14': 5}
        suits = {'S': 0, 'C': 1, 'D': 2, 'H': 3}
        trump_suit = curr_data['trump'][-1]
        game_type = curr_data['game_rules']['game_type']

        if len(curr_data['table']) > len(prev_data['table']):
            new_pair = curr_data['table'][-1]
            attack_card = new_pair['attack_card']['card']
            attack_user = new_pair['attack_card']['user_id']

            if attack_user == my_id:
                rank, suit = attack_card[:-1], attack_card[-1]
                card_idx = ranks[rank] * 4 + suits[suit]

                if game_type == 1 and prev_data['table']:
                    last_attack = prev_data['table'][-1]['attack_card']['card']
                    if last_attack[:-1] == attack_card[:-1]:
                        print(f"Detected transfer: {attack_card} matches {last_attack}")
                        return {'type': 'attack', 'card_idx': card_idx}
                return {'type': 'attack', 'card_idx': card_idx}

            if 'defend_card' in new_pair and new_pair['defend_card']['user_id'] == my_id:
                defend_card = new_pair['defend_card']['card']
                rank, suit = defend_card[:-1], defend_card[-1]
                card_idx = ranks[rank] * 4 + suits[suit]

                if not can_beat(attack_card, defend_card, trump_suit):
                    print(f"Invalid defend: {defend_card} cannot beat {attack_card}, trump={trump_suit}")
                    return {'type': 'invalid'}
                return {'type': 'defend', 'card_idx': card_idx}

        for curr_p, prev_p in zip(curr_data['players'], prev_data['players']):
            if curr_p['id'] == my_id and curr_p['state'] != prev_p['state']:
                if curr_p['state'] in ['bat', 'pass', 'take']:
                    state_map = {'bat': 0, 'pass': 1, 'take': 2}
                    print(f"State change detected: {prev_p['state']} -> {curr_p['state']}")
                    return {'type': 'state', 'state_idx': state_map[curr_p['state']]}

        if len(curr_data['table']) == 0 and len(prev_data['table']) > 0:
            for curr_p, prev_p in zip(curr_data['players'], prev_data['players']):
                if curr_p['id'] == my_id and curr_p['state'] == 'bat':
                    print("Detected 'bat' action: table cleared")
                    return {'type': 'state', 'state_idx': 0}

        return {'type': 'wait'}

    except Exception as e:
        print(f"Error in get_action: {e}")
        return {'type': 'invalid'}

# Обучение модели
def train_model(max_games=None, device='cpu'):
    print("Loading dataset...")
    dataset = load_dataset("neuronetties/durak")
    print("Dataset loaded.")

    model = DurakNet().to(device)
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    action_criterion = nn.CrossEntropyLoss()
    card_criterion = nn.CrossEntropyLoss()
    state_criterion = nn.CrossEntropyLoss()

    for name, param in model.named_parameters():
        if not param.requires_grad:
            print(f"Warning: Parameter {name} does not require grad!")

    games = defaultdict(list)
    for sample in dataset['train']:
        games[sample['game_id']].append(sample)

    if max_games is not None:
        game_ids = list(games.keys())[:max_games]
        games = {gid: games[gid] for gid in game_ids}

    total_games = len(games)
    print(f"Total games to process: {total_games}")

    action_counts = defaultdict(int)
    invalid_samples = 0

    epochs = 10
    for epoch in range(epochs):
        start_time = time.time()
        total_loss = 0.0
        num_samples = 0
        games_processed = 0

        for game_id, snapshots in games.items():
            print(f"Processing game {game_id}...")
            snapshots = sorted(snapshots, key=lambda x: json.loads(x['snapshot'])['timestamp'])

            try:
                my_id = json.loads(snapshots[0]['snapshot'])['players'][0]['id']
            except (KeyError, IndexError):
                print(f"Skipping game {game_id}: invalid player data")
                continue

            for i in range(len(snapshots) - 1):
                try:
                    state = encode_state(snapshots[i], my_id, device=device)
                    print(f"Snapshot {i}, state requires_grad: {state.requires_grad}")

                    # Проверка на nan/inf в state
                    if torch.isnan(state).any() or torch.isinf(state).any():
                        print(f"Invalid values in state for snapshot {i} in game {game_id}")
                        continue

                    action = get_action(snapshots[i], snapshots[i + 1], my_id)

                    if action['type'] == 'invalid':
                        invalid_samples += 1
                        continue

                    if action['type'] not in ['attack', 'defend', 'state', 'wait']:
                        print(f"Unknown action type: {action['type']}")
                        continue

                    action_counts[action['type']] += 1

                    action_logits, card_logits, state_logits = model(state.unsqueeze(0))

                    # Проверка, что выходы модели подключены к графу
                    print(f"action_logits grad_fn: {action_logits.grad_fn}")

                    loss = 0.0
                    if action['type'] == 'attack':
                        action_target = torch.tensor([0], dtype=torch.long, requires_grad=False, device=device)
                        card_target = torch.tensor([action['card_idx']], dtype=torch.long, requires_grad=False, device=device)
                        loss += action_criterion(action_logits, action_target)
                        loss += card_criterion(card_logits, card_target)
                    elif action['type'] == 'defend':
                        action_target = torch.tensor([1], dtype=torch.long, requires_grad=False, device=device)
                        card_target = torch.tensor([action['card_idx']], dtype=torch.long, requires_grad=False, device=device)
                        loss += action_criterion(action_logits, action_target)
                        loss += card_criterion(card_logits, card_target)
                    elif action['type'] == 'state':
                        action_target = torch.tensor([2], dtype=torch.long, requires_grad=False, device=device)
                        state_target = torch.tensor([action['state_idx']], dtype=torch.long, requires_grad=False, device=device)
                        loss += action_criterion(action_logits, action_target)
                        loss += state_criterion(state_logits, state_target)
                    else:
                        action_target = torch.tensor([3], dtype=torch.long, requires_grad=False, device=device)
                        loss += action_criterion(action_logits, action_target)

                    # Проверка на nan/inf в loss
                    if torch.isnan(loss) or torch.isinf(loss):
                        print(f"Loss is invalid: {loss}")
                        continue

                    optimizer.zero_grad()
                    loss.backward()
                    optimizer.step()

                    total_loss += loss.item()
                    num_samples += 1

                except Exception as e:
                    print(f"Error processing snapshot {i} in game {game_id}: {e}")
                    continue

            games_processed += 1
            if games_processed % 10 == 0:
                print(f"Epoch {epoch + 1}: Processed {games_processed}/{total_games} games ({games_processed/total_games*100:.1f}%)")

        elapsed_time = time.time() - start_time
        if num_samples > 0:
            print(f"Epoch {epoch + 1}, Loss: {total_loss / num_samples:.4f}, Samples: {num_samples}, Time: {elapsed_time:.2f}s")
        else:
            print(f"Epoch {epoch + 1}: No valid samples processed")

        print(f"Action distribution: {dict(action_counts)}")
        print(f"Invalid samples skipped: {invalid_samples}")

        checkpoint_path = f"durak_checkpoint_epoch_{epoch + 1}.pth"
        torch.save(model.state_dict(), checkpoint_path)
        print(f"Checkpoint saved to {checkpoint_path}")

    print("Saving final model...")
    torch.save(model.state_dict(), "durak_model.pth")
    print("Model weights saved to durak_model.pth")

    return model

# Предсказание действия
def predict_action(model, snapshot, my_id, device='cpu'):
    model.eval()
    with torch.no_grad():
        state = encode_state(snapshot, my_id, device=device)
        action_logits, card_logits, state_logits = model(state.unsqueeze(0))

        print(f"action_logits: {action_logits}")

        action_idx = torch.argmax(action_logits, dim=1).item()
        action_map = {0: 'attack', 1: 'defend', 2: 'state', 3: 'wait'}
        action_type = action_map[action_idx]

        if action_type == 'attack' or action_type == 'defend':
            card_idx = torch.argmax(card_logits, dim=1).item()
            ranks = {0: '9', 1: '10', 2: '11', 3: '12', 4: '13', 5: '14'}
            suits = {0: 'S', 1: 'C', 2: 'D', 3: 'H'}
            card = f"{ranks[card_idx // 4]}{suits[card_idx % 4]}"
            return {"type": action_type, "move": card}
        elif action_type == 'state':
            state_idx = torch.argmax(state_logits, dim=1).item()
            state_map = {0: 'bat', 1: 'pass', 2: 'take'}
            return {"type": "state", "state": state_map[state_idx]}
        else:
            return {"type": "wait"}

# Загрузка модели
def load_model(model_path="durak_model.pth", device='cpu'):
    model = DurakNet().to(device)
    if os.path.exists(model_path):
        model.load_state_dict(torch.load(model_path, map_location=device))
        model.eval()
        print(f"Model weights loaded from {model_path}")
        return model
    else:
        print(f"Model file {model_path} not found")
        return None

if __name__ == "__main__":
    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    print(f"Using device: {device}")

    model = train_model(max_games=100, device=device)

    print("Testing predictions...")
    dataset = load_dataset("neuronetties/durak")
    for i in range(3):
        sample = dataset['train'][i]
        my_id = json.loads(sample['snapshot'])['players'][0]['id']
        action = predict_action(model, sample, my_id, device=device)
        print(f"Sample {i}: Predicted action: {action}")

    loaded_model = load_model("durak_model.pth", device=device)
    if loaded_model:
        action = predict_action(loaded_model, dataset['train'][0], my_id, device=device)
        print(f"Loaded model prediction: {action}")
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# action_logits grad_fn: None
# Error processing snapshot 35 in game ee966a6f-4066-418a-be55-06f66a32c877: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 36, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 36 in game ee966a6f-4066-418a-be55-06f66a32c877: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 37, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 37 in game ee966a6f-4066-418a-be55-06f66a32c877: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 38, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 38 in game ee966a6f-4066-418a-be55-06f66a32c877: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 39, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 39 in game ee966a6f-4066-418a-be55-06f66a32c877: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 40, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 40 in game ee966a6f-4066-418a-be55-06f66a32c877: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 41, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 41 in game ee966a6f-4066-418a-be55-06f66a32c877: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 42, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 42 in game ee966a6f-4066-418a-be55-06f66a32c877: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 43, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 43 in game ee966a6f-4066-418a-be55-06f66a32c877: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 44, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 44 in game ee966a6f-4066-418a-be55-06f66a32c877: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 45, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 45 in game ee966a6f-4066-418a-be55-06f66a32c877: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 46, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 46 in game ee966a6f-4066-418a-be55-06f66a32c877: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 47, state requires_grad: True
# State change detected: attack -> bat
# action_logits grad_fn: None
# Error processing snapshot 47 in game ee966a6f-4066-418a-be55-06f66a32c877: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 48, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 48 in game ee966a6f-4066-418a-be55-06f66a32c877: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 49, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 49 in game ee966a6f-4066-418a-be55-06f66a32c877: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 50, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 50 in game ee966a6f-4066-418a-be55-06f66a32c877: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 51, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 51 in game ee966a6f-4066-418a-be55-06f66a32c877: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 52, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 52 in game ee966a6f-4066-418a-be55-06f66a32c877: element 0 of tensors does not require grad and does not have a grad_fn
# Processing game 7cd4bca8-d798-48db-a9d1-afdbca030183...
# Snapshot 0, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 0 in game 7cd4bca8-d798-48db-a9d1-afdbca030183: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 1, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 1 in game 7cd4bca8-d798-48db-a9d1-afdbca030183: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 2, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 2 in game 7cd4bca8-d798-48db-a9d1-afdbca030183: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 3, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 3 in game 7cd4bca8-d798-48db-a9d1-afdbca030183: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 4, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 4 in game 7cd4bca8-d798-48db-a9d1-afdbca030183: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 5, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 5 in game 7cd4bca8-d798-48db-a9d1-afdbca030183: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 6, state requires_grad: True
# State change detected: attack -> bat
# action_logits grad_fn: None
# Error processing snapshot 6 in game 7cd4bca8-d798-48db-a9d1-afdbca030183: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 7, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 7 in game 7cd4bca8-d798-48db-a9d1-afdbca030183: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 8, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 8 in game 7cd4bca8-d798-48db-a9d1-afdbca030183: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 9, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 9 in game 7cd4bca8-d798-48db-a9d1-afdbca030183: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 10, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 10 in game 7cd4bca8-d798-48db-a9d1-afdbca030183: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 11, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 11 in game 7cd4bca8-d798-48db-a9d1-afdbca030183: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 12, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 12 in game 7cd4bca8-d798-48db-a9d1-afdbca030183: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 13, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 13 in game 7cd4bca8-d798-48db-a9d1-afdbca030183: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 14, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 14 in game 7cd4bca8-d798-48db-a9d1-afdbca030183: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 15, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 15 in game 7cd4bca8-d798-48db-a9d1-afdbca030183: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 16, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 16 in game 7cd4bca8-d798-48db-a9d1-afdbca030183: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 17, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 17 in game 7cd4bca8-d798-48db-a9d1-afdbca030183: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 18, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 18 in game 7cd4bca8-d798-48db-a9d1-afdbca030183: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 19, state requires_grad: True
# State change detected: defend -> take
# action_logits grad_fn: None
# Error processing snapshot 19 in game 7cd4bca8-d798-48db-a9d1-afdbca030183: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 20, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 20 in game 7cd4bca8-d798-48db-a9d1-afdbca030183: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 21, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 21 in game 7cd4bca8-d798-48db-a9d1-afdbca030183: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 22, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 22 in game 7cd4bca8-d798-48db-a9d1-afdbca030183: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 23, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 23 in game 7cd4bca8-d798-48db-a9d1-afdbca030183: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 24, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 24 in game 7cd4bca8-d798-48db-a9d1-afdbca030183: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 25, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 25 in game 7cd4bca8-d798-48db-a9d1-afdbca030183: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 26, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 26 in game 7cd4bca8-d798-48db-a9d1-afdbca030183: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 27, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 27 in game 7cd4bca8-d798-48db-a9d1-afdbca030183: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 28, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 28 in game 7cd4bca8-d798-48db-a9d1-afdbca030183: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 29, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 29 in game 7cd4bca8-d798-48db-a9d1-afdbca030183: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 30, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 30 in game 7cd4bca8-d798-48db-a9d1-afdbca030183: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 31, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 31 in game 7cd4bca8-d798-48db-a9d1-afdbca030183: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 32, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 32 in game 7cd4bca8-d798-48db-a9d1-afdbca030183: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 33, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 33 in game 7cd4bca8-d798-48db-a9d1-afdbca030183: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 34, state requires_grad: True
# State change detected: attack -> pass
# action_logits grad_fn: None
# Error processing snapshot 34 in game 7cd4bca8-d798-48db-a9d1-afdbca030183: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 35, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 35 in game 7cd4bca8-d798-48db-a9d1-afdbca030183: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 36, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 36 in game 7cd4bca8-d798-48db-a9d1-afdbca030183: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 37, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 37 in game 7cd4bca8-d798-48db-a9d1-afdbca030183: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 38, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 38 in game 7cd4bca8-d798-48db-a9d1-afdbca030183: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 39, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 39 in game 7cd4bca8-d798-48db-a9d1-afdbca030183: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 40, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 40 in game 7cd4bca8-d798-48db-a9d1-afdbca030183: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 41, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 41 in game 7cd4bca8-d798-48db-a9d1-afdbca030183: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 42, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 42 in game 7cd4bca8-d798-48db-a9d1-afdbca030183: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 43, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 43 in game 7cd4bca8-d798-48db-a9d1-afdbca030183: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 44, state requires_grad: True
# State change detected: attack -> pass
# action_logits grad_fn: None
# Error processing snapshot 44 in game 7cd4bca8-d798-48db-a9d1-afdbca030183: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 45, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 45 in game 7cd4bca8-d798-48db-a9d1-afdbca030183: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 46, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 46 in game 7cd4bca8-d798-48db-a9d1-afdbca030183: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 47, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 47 in game 7cd4bca8-d798-48db-a9d1-afdbca030183: element 0 of tensors does not require grad and does not have a grad_fn
# Processing game 3317ea2a-3b48-48d0-9695-d464168d9dd7...
# Snapshot 0, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 0 in game 3317ea2a-3b48-48d0-9695-d464168d9dd7: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 1, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 1 in game 3317ea2a-3b48-48d0-9695-d464168d9dd7: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 2, state requires_grad: True
# State change detected: attack -> pass
# action_logits grad_fn: None
# Error processing snapshot 2 in game 3317ea2a-3b48-48d0-9695-d464168d9dd7: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 3, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 3 in game 3317ea2a-3b48-48d0-9695-d464168d9dd7: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 4, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 4 in game 3317ea2a-3b48-48d0-9695-d464168d9dd7: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 5, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 5 in game 3317ea2a-3b48-48d0-9695-d464168d9dd7: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 6, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 6 in game 3317ea2a-3b48-48d0-9695-d464168d9dd7: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 7, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 7 in game 3317ea2a-3b48-48d0-9695-d464168d9dd7: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 8, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 8 in game 3317ea2a-3b48-48d0-9695-d464168d9dd7: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 9, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 9 in game 3317ea2a-3b48-48d0-9695-d464168d9dd7: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 10, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 10 in game 3317ea2a-3b48-48d0-9695-d464168d9dd7: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 11, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 11 in game 3317ea2a-3b48-48d0-9695-d464168d9dd7: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 12, state requires_grad: True
# State change detected: attack -> bat
# action_logits grad_fn: None
# Error processing snapshot 12 in game 3317ea2a-3b48-48d0-9695-d464168d9dd7: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 13, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 13 in game 3317ea2a-3b48-48d0-9695-d464168d9dd7: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 14, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 14 in game 3317ea2a-3b48-48d0-9695-d464168d9dd7: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 15, state requires_grad: True
# State change detected: defend -> take
# action_logits grad_fn: None
# Error processing snapshot 15 in game 3317ea2a-3b48-48d0-9695-d464168d9dd7: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 16, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 16 in game 3317ea2a-3b48-48d0-9695-d464168d9dd7: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 17, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 17 in game 3317ea2a-3b48-48d0-9695-d464168d9dd7: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 18, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 18 in game 3317ea2a-3b48-48d0-9695-d464168d9dd7: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 19, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 19 in game 3317ea2a-3b48-48d0-9695-d464168d9dd7: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 20, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 20 in game 3317ea2a-3b48-48d0-9695-d464168d9dd7: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 21, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 21 in game 3317ea2a-3b48-48d0-9695-d464168d9dd7: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 22, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 22 in game 3317ea2a-3b48-48d0-9695-d464168d9dd7: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 23, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 23 in game 3317ea2a-3b48-48d0-9695-d464168d9dd7: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 24, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 24 in game 3317ea2a-3b48-48d0-9695-d464168d9dd7: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 25, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 25 in game 3317ea2a-3b48-48d0-9695-d464168d9dd7: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 26, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 26 in game 3317ea2a-3b48-48d0-9695-d464168d9dd7: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 27, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 27 in game 3317ea2a-3b48-48d0-9695-d464168d9dd7: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 28, state requires_grad: True
# Detected transfer: 11S matches 11D
# action_logits grad_fn: None
# Error processing snapshot 28 in game 3317ea2a-3b48-48d0-9695-d464168d9dd7: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 29, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 29 in game 3317ea2a-3b48-48d0-9695-d464168d9dd7: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 30, state requires_grad: True
# State change detected: attack -> bat
# action_logits grad_fn: None
# Error processing snapshot 30 in game 3317ea2a-3b48-48d0-9695-d464168d9dd7: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 31, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 31 in game 3317ea2a-3b48-48d0-9695-d464168d9dd7: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 32, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 32 in game 3317ea2a-3b48-48d0-9695-d464168d9dd7: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 33, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 33 in game 3317ea2a-3b48-48d0-9695-d464168d9dd7: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 34, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 34 in game 3317ea2a-3b48-48d0-9695-d464168d9dd7: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 35, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 35 in game 3317ea2a-3b48-48d0-9695-d464168d9dd7: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 36, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 36 in game 3317ea2a-3b48-48d0-9695-d464168d9dd7: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 37, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 37 in game 3317ea2a-3b48-48d0-9695-d464168d9dd7: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 38, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 38 in game 3317ea2a-3b48-48d0-9695-d464168d9dd7: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 39, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 39 in game 3317ea2a-3b48-48d0-9695-d464168d9dd7: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 40, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 40 in game 3317ea2a-3b48-48d0-9695-d464168d9dd7: element 0 of tensors does not require grad and does not have a grad_fn
# Processing game ea815320-8b14-411b-bcdd-be16a24c05a2...
# Snapshot 0, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 0 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 1, state requires_grad: True
# Detected transfer: 10D matches 10C
# action_logits grad_fn: None
# Error processing snapshot 1 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 2, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 2 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 3, state requires_grad: True
# State change detected: attack -> pass
# action_logits grad_fn: None
# Error processing snapshot 3 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 4, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 4 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 5, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 5 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 6, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 6 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 7, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 7 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 8, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 8 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 9, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 9 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 10, state requires_grad: True
# State change detected: defend -> take
# action_logits grad_fn: None
# Error processing snapshot 10 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 11, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 11 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 12, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 12 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 13, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 13 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 14, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 14 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 15, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 15 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 16, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 16 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 17, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 17 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 18, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 18 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 19, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 19 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 20, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 20 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 21, state requires_grad: True
# State change detected: attack -> bat
# action_logits grad_fn: None
# Error processing snapshot 21 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 22, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 22 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 23, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 23 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 24, state requires_grad: True
# Detected transfer: 9D matches 9S
# action_logits grad_fn: None
# Error processing snapshot 24 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 25, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 25 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 26, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 26 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 27, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 27 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 28, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 28 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 29, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 29 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 30, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 30 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 31, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 31 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 32, state requires_grad: True
# State change detected: defend -> take
# action_logits grad_fn: None
# Error processing snapshot 32 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 33, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 33 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 34, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 34 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 35, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 35 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 36, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 36 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 37, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 37 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 38, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 38 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 39, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 39 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 40, state requires_grad: True
# Detected transfer: 9S matches 9D
# action_logits grad_fn: None
# Error processing snapshot 40 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 41, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 41 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 42, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 42 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 43, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 43 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 44, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 44 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 45, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 45 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 46, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 46 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 47, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 47 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 48, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 48 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 49, state requires_grad: True
# State change detected: attack -> pass
# action_logits grad_fn: None
# Error processing snapshot 49 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 50, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 50 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 51, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 51 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 52, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 52 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 53, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 53 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 54, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 54 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 55, state requires_grad: True
# State change detected: attack -> bat
# action_logits grad_fn: None
# Error processing snapshot 55 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 56, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 56 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 57, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 57 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 58, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 58 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 59, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 59 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 60, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 60 in game ea815320-8b14-411b-bcdd-be16a24c05a2: element 0 of tensors does not require grad and does not have a grad_fn
# Processing game 368a3d6b-d74a-4e50-b1e3-0edd814569d4...
# Snapshot 0, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 0 in game 368a3d6b-d74a-4e50-b1e3-0edd814569d4: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 1, state requires_grad: True
# State change detected: defend -> take
# action_logits grad_fn: None
# Error processing snapshot 1 in game 368a3d6b-d74a-4e50-b1e3-0edd814569d4: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 2, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 2 in game 368a3d6b-d74a-4e50-b1e3-0edd814569d4: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 3, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 3 in game 368a3d6b-d74a-4e50-b1e3-0edd814569d4: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 4, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 4 in game 368a3d6b-d74a-4e50-b1e3-0edd814569d4: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 5, state requires_grad: True
# Detected transfer: 11S matches 11C
# action_logits grad_fn: None
# Error processing snapshot 5 in game 368a3d6b-d74a-4e50-b1e3-0edd814569d4: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 6, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 6 in game 368a3d6b-d74a-4e50-b1e3-0edd814569d4: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 7, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 7 in game 368a3d6b-d74a-4e50-b1e3-0edd814569d4: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 8, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 8 in game 368a3d6b-d74a-4e50-b1e3-0edd814569d4: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 9, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 9 in game 368a3d6b-d74a-4e50-b1e3-0edd814569d4: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 10, state requires_grad: True
# State change detected: attack -> bat
# action_logits grad_fn: None
# Error processing snapshot 10 in game 368a3d6b-d74a-4e50-b1e3-0edd814569d4: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 11, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 11 in game 368a3d6b-d74a-4e50-b1e3-0edd814569d4: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 12, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 12 in game 368a3d6b-d74a-4e50-b1e3-0edd814569d4: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 13, state requires_grad: True
# Detected transfer: 9S matches 9C
# action_logits grad_fn: None
# Error processing snapshot 13 in game 368a3d6b-d74a-4e50-b1e3-0edd814569d4: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 14, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 14 in game 368a3d6b-d74a-4e50-b1e3-0edd814569d4: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 15, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 15 in game 368a3d6b-d74a-4e50-b1e3-0edd814569d4: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 16, state requires_grad: True
# State change detected: attack -> bat
# action_logits grad_fn: None
# Error processing snapshot 16 in game 368a3d6b-d74a-4e50-b1e3-0edd814569d4: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 17, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 17 in game 368a3d6b-d74a-4e50-b1e3-0edd814569d4: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 18, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 18 in game 368a3d6b-d74a-4e50-b1e3-0edd814569d4: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 19, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 19 in game 368a3d6b-d74a-4e50-b1e3-0edd814569d4: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 20, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 20 in game 368a3d6b-d74a-4e50-b1e3-0edd814569d4: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 21, state requires_grad: True
# State change detected: defend -> take
# action_logits grad_fn: None
# Error processing snapshot 21 in game 368a3d6b-d74a-4e50-b1e3-0edd814569d4: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 22, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 22 in game 368a3d6b-d74a-4e50-b1e3-0edd814569d4: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 23, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 23 in game 368a3d6b-d74a-4e50-b1e3-0edd814569d4: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 24, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 24 in game 368a3d6b-d74a-4e50-b1e3-0edd814569d4: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 25, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 25 in game 368a3d6b-d74a-4e50-b1e3-0edd814569d4: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 26, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 26 in game 368a3d6b-d74a-4e50-b1e3-0edd814569d4: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 27, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 27 in game 368a3d6b-d74a-4e50-b1e3-0edd814569d4: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 28, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 28 in game 368a3d6b-d74a-4e50-b1e3-0edd814569d4: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 29, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 29 in game 368a3d6b-d74a-4e50-b1e3-0edd814569d4: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 30, state requires_grad: True
# Detected transfer: 9D matches 9H
# action_logits grad_fn: None
# Error processing snapshot 30 in game 368a3d6b-d74a-4e50-b1e3-0edd814569d4: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 31, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 31 in game 368a3d6b-d74a-4e50-b1e3-0edd814569d4: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 32, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 32 in game 368a3d6b-d74a-4e50-b1e3-0edd814569d4: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 33, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 33 in game 368a3d6b-d74a-4e50-b1e3-0edd814569d4: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 34, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 34 in game 368a3d6b-d74a-4e50-b1e3-0edd814569d4: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 35, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 35 in game 368a3d6b-d74a-4e50-b1e3-0edd814569d4: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 36, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 36 in game 368a3d6b-d74a-4e50-b1e3-0edd814569d4: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 37, state requires_grad: True
# State change detected: attack -> pass
# action_logits grad_fn: None
# Error processing snapshot 37 in game 368a3d6b-d74a-4e50-b1e3-0edd814569d4: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 38, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 38 in game 368a3d6b-d74a-4e50-b1e3-0edd814569d4: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 39, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 39 in game 368a3d6b-d74a-4e50-b1e3-0edd814569d4: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 40, state requires_grad: True
# Detected transfer: 10S matches 10C
# action_logits grad_fn: None
# Error processing snapshot 40 in game 368a3d6b-d74a-4e50-b1e3-0edd814569d4: element 0 of tensors does not require grad and does not have a grad_fn
# Processing game 002043f9-3350-480e-a707-4e92a27341b9...
# Snapshot 0, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 0 in game 002043f9-3350-480e-a707-4e92a27341b9: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 1, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 1 in game 002043f9-3350-480e-a707-4e92a27341b9: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 2, state requires_grad: True
# State change detected: attack -> bat
# action_logits grad_fn: None
# Error processing snapshot 2 in game 002043f9-3350-480e-a707-4e92a27341b9: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 3, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 3 in game 002043f9-3350-480e-a707-4e92a27341b9: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 4, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 4 in game 002043f9-3350-480e-a707-4e92a27341b9: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 5, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 5 in game 002043f9-3350-480e-a707-4e92a27341b9: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 6, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 6 in game 002043f9-3350-480e-a707-4e92a27341b9: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 7, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 7 in game 002043f9-3350-480e-a707-4e92a27341b9: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 8, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 8 in game 002043f9-3350-480e-a707-4e92a27341b9: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 9, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 9 in game 002043f9-3350-480e-a707-4e92a27341b9: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 10, state requires_grad: True
# action_logits grad_fn: None
# ...
# Error processing snapshot 15 in game a06baee2-0415-4114-8ee1-c3ee8d914442: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 16, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 16 in game a06baee2-0415-4114-8ee1-c3ee8d914442: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 17, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 17 in game a06baee2-0415-4114-8ee1-c3ee8d914442: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 18, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 18 in game a06baee2-0415-4114-8ee1-c3ee8d914442: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 19, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 19 in game a06baee2-0415-4114-8ee1-c3ee8d914442: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 20, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 20 in game a06baee2-0415-4114-8ee1-c3ee8d914442: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 21, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 21 in game a06baee2-0415-4114-8ee1-c3ee8d914442: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 22, state requires_grad: True
# Detected transfer: 9S matches 9C
# action_logits grad_fn: None
# Error processing snapshot 22 in game a06baee2-0415-4114-8ee1-c3ee8d914442: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 23, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 23 in game a06baee2-0415-4114-8ee1-c3ee8d914442: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 24, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 24 in game a06baee2-0415-4114-8ee1-c3ee8d914442: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 25, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 25 in game a06baee2-0415-4114-8ee1-c3ee8d914442: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 26, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 26 in game a06baee2-0415-4114-8ee1-c3ee8d914442: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 27, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 27 in game a06baee2-0415-4114-8ee1-c3ee8d914442: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 28, state requires_grad: True
# State change detected: attack -> bat
# action_logits grad_fn: None
# Error processing snapshot 28 in game a06baee2-0415-4114-8ee1-c3ee8d914442: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 29, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 29 in game a06baee2-0415-4114-8ee1-c3ee8d914442: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 30, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 30 in game a06baee2-0415-4114-8ee1-c3ee8d914442: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 31, state requires_grad: True
# State change detected: defend -> take
# action_logits grad_fn: None
# Error processing snapshot 31 in game a06baee2-0415-4114-8ee1-c3ee8d914442: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 32, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 32 in game a06baee2-0415-4114-8ee1-c3ee8d914442: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 33, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 33 in game a06baee2-0415-4114-8ee1-c3ee8d914442: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 34, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 34 in game a06baee2-0415-4114-8ee1-c3ee8d914442: element 0 of tensors does not require grad and does not have a grad_fn
# Processing game f621615f-5b09-4bed-865c-4f65515c6e1b...
# Snapshot 0, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 0 in game f621615f-5b09-4bed-865c-4f65515c6e1b: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 1, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 1 in game f621615f-5b09-4bed-865c-4f65515c6e1b: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 2, state requires_grad: True
# Detected transfer: 12D matches 12C
# action_logits grad_fn: None
# Error processing snapshot 2 in game f621615f-5b09-4bed-865c-4f65515c6e1b: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 3, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 3 in game f621615f-5b09-4bed-865c-4f65515c6e1b: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 4, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 4 in game f621615f-5b09-4bed-865c-4f65515c6e1b: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 5, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 5 in game f621615f-5b09-4bed-865c-4f65515c6e1b: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 6, state requires_grad: True
# Detected transfer: 14H matches 14C
# action_logits grad_fn: None
# Error processing snapshot 6 in game f621615f-5b09-4bed-865c-4f65515c6e1b: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 7, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 7 in game f621615f-5b09-4bed-865c-4f65515c6e1b: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 8, state requires_grad: True
# State change detected: attack -> pass
# action_logits grad_fn: None
# Error processing snapshot 8 in game f621615f-5b09-4bed-865c-4f65515c6e1b: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 9, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 9 in game f621615f-5b09-4bed-865c-4f65515c6e1b: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 10, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 10 in game f621615f-5b09-4bed-865c-4f65515c6e1b: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 11, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 11 in game f621615f-5b09-4bed-865c-4f65515c6e1b: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 12, state requires_grad: True
# State change detected: attack -> bat
# action_logits grad_fn: None
# Error processing snapshot 12 in game f621615f-5b09-4bed-865c-4f65515c6e1b: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 13, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 13 in game f621615f-5b09-4bed-865c-4f65515c6e1b: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 14, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 14 in game f621615f-5b09-4bed-865c-4f65515c6e1b: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 15, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 15 in game f621615f-5b09-4bed-865c-4f65515c6e1b: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 16, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 16 in game f621615f-5b09-4bed-865c-4f65515c6e1b: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 17, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 17 in game f621615f-5b09-4bed-865c-4f65515c6e1b: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 18, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 18 in game f621615f-5b09-4bed-865c-4f65515c6e1b: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 19, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 19 in game f621615f-5b09-4bed-865c-4f65515c6e1b: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 20, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 20 in game f621615f-5b09-4bed-865c-4f65515c6e1b: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 21, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 21 in game f621615f-5b09-4bed-865c-4f65515c6e1b: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 22, state requires_grad: True
# State change detected: attack -> bat
# action_logits grad_fn: None
# Error processing snapshot 22 in game f621615f-5b09-4bed-865c-4f65515c6e1b: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 23, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 23 in game f621615f-5b09-4bed-865c-4f65515c6e1b: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 24, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 24 in game f621615f-5b09-4bed-865c-4f65515c6e1b: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 25, state requires_grad: True
# Detected transfer: 12H matches 12D
# action_logits grad_fn: None
# Error processing snapshot 25 in game f621615f-5b09-4bed-865c-4f65515c6e1b: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 26, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 26 in game f621615f-5b09-4bed-865c-4f65515c6e1b: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 27, state requires_grad: True
# State change detected: defend -> take
# action_logits grad_fn: None
# Error processing snapshot 27 in game f621615f-5b09-4bed-865c-4f65515c6e1b: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 28, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 28 in game f621615f-5b09-4bed-865c-4f65515c6e1b: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 29, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 29 in game f621615f-5b09-4bed-865c-4f65515c6e1b: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 30, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 30 in game f621615f-5b09-4bed-865c-4f65515c6e1b: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 31, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 31 in game f621615f-5b09-4bed-865c-4f65515c6e1b: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 32, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 32 in game f621615f-5b09-4bed-865c-4f65515c6e1b: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 33, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 33 in game f621615f-5b09-4bed-865c-4f65515c6e1b: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 34, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 34 in game f621615f-5b09-4bed-865c-4f65515c6e1b: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 35, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 35 in game f621615f-5b09-4bed-865c-4f65515c6e1b: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 36, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 36 in game f621615f-5b09-4bed-865c-4f65515c6e1b: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 37, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 37 in game f621615f-5b09-4bed-865c-4f65515c6e1b: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 38, state requires_grad: True
# Detected transfer: 12C matches 12D
# action_logits grad_fn: None
# Error processing snapshot 38 in game f621615f-5b09-4bed-865c-4f65515c6e1b: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 39, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 39 in game f621615f-5b09-4bed-865c-4f65515c6e1b: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 40, state requires_grad: True
# Detected transfer: 12H matches 12C
# action_logits grad_fn: None
# Error processing snapshot 40 in game f621615f-5b09-4bed-865c-4f65515c6e1b: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 41, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 41 in game f621615f-5b09-4bed-865c-4f65515c6e1b: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 42, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 42 in game f621615f-5b09-4bed-865c-4f65515c6e1b: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 43, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 43 in game f621615f-5b09-4bed-865c-4f65515c6e1b: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 44, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 44 in game f621615f-5b09-4bed-865c-4f65515c6e1b: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 45, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 45 in game f621615f-5b09-4bed-865c-4f65515c6e1b: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 46, state requires_grad: True
# State change detected: attack -> pass
# action_logits grad_fn: None
# Error processing snapshot 46 in game f621615f-5b09-4bed-865c-4f65515c6e1b: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 47, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 47 in game f621615f-5b09-4bed-865c-4f65515c6e1b: element 0 of tensors does not require grad and does not have a grad_fn
# Snapshot 48, state requires_grad: True
# action_logits grad_fn: None
# Error processing snapshot 48 in game f621615f-5b09-4bed-865c-4f65515c6e1b: element 0 of tensors does not require grad and does not have a grad_fn
# Epoch 10: Processed 100/100 games (100.0%)
# Epoch 10: No valid samples processed
# Action distribution: {'attack': 8900, 'wait': 32960, 'state': 5450}
# Invalid samples skipped: 0
# Checkpoint saved to durak_checkpoint_epoch_10.pth
# Saving final model...
# Model weights saved to durak_model.pth
# Testing predictions...
# action_logits: tensor([[ 0.0369,  0.0978, -0.0050,  0.0151]])
# Sample 0: Predicted action: {'type': 'defend', 'move': '11S'}
# action_logits: tensor([[ 0.0418,  0.1004, -0.0080,  0.0144]])
# Sample 1: Predicted action: {'type': 'defend', 'move': '11S'}
# action_logits: tensor([[ 0.0350,  0.0949, -0.0169,  0.0106]])
# Sample 2: Predicted action: {'type': 'defend', 'move': '11S'}
# Model weights loaded from durak_model.pth
# action_logits: tensor([[ 0.0369,  0.0978, -0.0050,  0.0151]])
# Loaded model prediction: {'type': 'defend', 'move': '11S'}

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from datasets import load_dataset
from collections import defaultdict
import json
import time
import os

# Модель нейросети
class DurakNet(nn.Module):
    def __init__(self, input_dim=128, hidden_dim=256, num_cards=24, num_actions=4):
        super(DurakNet, self).__init__()

        self.state_encoder = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim // 2),
            nn.ReLU()
        )

        self.action_head = nn.Linear(hidden_dim // 2, num_actions)
        self.card_head = nn.Linear(hidden_dim // 2, num_cards)
        self.state_head = nn.Linear(hidden_dim // 2, 3)

    def forward(self, state):
        encoded = self.state_encoder(state)
        action_logits = self.action_head(encoded)
        card_logits = self.card_head(encoded)
        state_logits = self.state_head(encoded)
        return action_logits, card_logits, state_logits

# Кодирование состояния на основе предложенной структуры
def encode_state(snapshot, my_id, device='cpu'):
    try:
        data = json.loads(snapshot['snapshot'])

        # Инициализация вектора состояния
        state = np.zeros(128, dtype=np.float32)

        # Козырь (trump)
        trump = data['trump']
        suits = {'S': 0, 'C': 1, 'D': 2, 'H': 3}
        ranks = {'9': 0, '10': 1, '11': 2, '12': 3, '13': 4, '14': 5}
        trump_rank, trump_suit = trump[:-1], trump[-1]
        state[0 + suits[trump_suit]] = 1.0  # Кодируем масть козыря
        state[4 + ranks[trump_rank]] = 1.0  # Кодируем ранг козыря

        # Карты игрока (my_id)
        for player in data['players']:
            if player['id'] == my_id:
                for card in player['hand']:
                    rank, suit = card[:-1], card[-1]
                    card_idx = ranks[rank] * 4 + suits[suit]
                    state[10 + card_idx] = 1.0  # Кодируем карты на руке

        # Карты на столе (table)
        for i, pair in enumerate(data['table'][:4]):  # Ограничиваем до 4 пар
            attack_card = pair['attack_card']['card']
            rank, suit = attack_card[:-1], attack_card[-1]
            state[34 + i * 12 + ranks[rank]] = 1.0  # Кодируем ранг атакующей карты
            state[34 + i *12 + 6 + suits[suit]] = 1.0  # Кодируем масть атакующей карты
            if 'defend_card' in pair:
                defend_card = pair['defend_card']['card']
                rank, suit = defend_card[:-1], defend_card[-1]
                state[82 + i * 12 + ranks[rank]] = 1.0  # Кодируем ранг защитной карты
                state[82 + i * 12 + 6 + suits[suit]] = 1.0  # Кодируем масть защитной карты

        # Колода (deck)
        state[114] = len(data['deck']) / 24.0  # Нормализованное количество карт в колоде

        # Состояние игрока (state)
        for player in data['players']:
            if player['id'] == my_id:
                state_map = {'attack': 115, 'defend': 116, 'bat': 117, 'pass': 118, 'take': 119}
                if player['state'] in state_map:
                    state[state_map[player['state']]] = 1.0

        # Режим игры (game_type)
        state[120] = data['game_rules']['game_type']

        # Создаем тензор
        tensor = torch.tensor(state, dtype=torch.float32, device=device, requires_grad=True)
        return tensor

    except Exception as e:
        print(f"Error in encode_state: {e}")
        return torch.zeros(128, dtype=torch.float32, device=device)

# Проверка, может ли defend_card побить attack_card
def can_beat(attack_card, defend_card, trump_suit):
    suits = {'S': 0, 'C': 1, 'D': 2, 'H': 3}
    ranks = {'9': 0, '10': 1, '11': 2, '12': 3, '13': 4, '14': 5}

    attack_rank, attack_suit = attack_card[:-1], attack_card[-1]
    defend_rank, defend_suit = defend_card[:-1], defend_card[-1]

    attack_rank_idx = ranks[attack_rank]
    defend_rank_idx = ranks[defend_rank]
    attack_suit_idx = suits[attack_suit]
    defend_suit_idx = suits[defend_suit]
    trump_suit_idx = suits[trump_suit]

    if attack_suit_idx == defend_suit_idx:
        return defend_rank_idx > attack_rank_idx
    elif defend_suit_idx == trump_suit_idx and attack_suit_idx != trump_suit_idx:
        return True
    return False

# Извлечение действия
def get_action(prev_snapshot, curr_snapshot, my_id):
    try:
        prev_data = json.loads(prev_snapshot['snapshot'])
        curr_data = json.loads(curr_snapshot['snapshot'])

        ranks = {'9': 0, '10': 1, '11': 2, '12': 3, '13': 4, '14': 5}
        suits = {'S': 0, 'C': 1, 'D': 2, 'H': 3}
        trump_suit = curr_data['trump'][-1]
        game_type = curr_data['game_rules']['game_type']

        if len(curr_data['table']) > len(prev_data['table']):
            new_pair = curr_data['table'][-1]
            attack_card = new_pair['attack_card']['card']
            attack_user = new_pair['attack_card']['user_id']

            if attack_user == my_id:
                rank, suit = attack_card[:-1], attack_card[-1]
                card_idx = ranks[rank] * 4 + suits[suit]

                if game_type == 1 and prev_data['table']:
                    last_attack = prev_data['table'][-1]['attack_card']['card']
                    if last_attack[:-1] == attack_card[:-1]:
                        print(f"Detected transfer: {attack_card} matches {last_attack}")
                        return {'type': 'attack', 'card_idx': card_idx}
                return {'type': 'attack', 'card_idx': card_idx}

            if 'defend_card' in new_pair and new_pair['defend_card']['user_id'] == my_id:
                defend_card = new_pair['defend_card']['card']
                rank, suit = defend_card[:-1], defend_card[-1]
                card_idx = ranks[rank] * 4 + suits[suit]

                if not can_beat(attack_card, defend_card, trump_suit):
                    print(f"Invalid defend: {defend_card} cannot beat {attack_card}, trump={trump_suit}")
                    return {'type': 'invalid'}
                return {'type': 'defend', 'card_idx': card_idx}

        for curr_p, prev_p in zip(curr_data['players'], prev_data['players']):
            if curr_p['id'] == my_id and curr_p['state'] != prev_p['state']:
                if curr_p['state'] in ['bat', 'pass', 'take']:
                    state_map = {'bat': 0, 'pass': 1, 'take': 2}
                    print(f"State change detected: {prev_p['state']} -> {curr_p['state']}")
                    return {'type': 'state', 'state_idx': state_map[curr_p['state']]}

        if len(curr_data['table']) == 0 and len(prev_data['table']) > 0:
            for curr_p, prev_p in zip(curr_data['players'], prev_data['players']):
                if curr_p['id'] == my_id and curr_p['state'] == 'bat':
                    print("Detected 'bat' action: table cleared")
                    return {'type': 'state', 'state_idx': 0}

        return {'type': 'wait'}

    except Exception as e:
        print(f"Error in get_action: {e}")
        return {'type': 'invalid'}

# Обучение модели
def train_model(max_games=None, device='cpu'):
    print("Loading dataset...")
    dataset = load_dataset("neuronetties/durak")
    print("Dataset loaded.")

    model = DurakNet().to(device)
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    action_criterion = nn.CrossEntropyLoss()
    card_criterion = nn.CrossEntropyLoss()
    state_criterion = nn.CrossEntropyLoss()

    # Проверка параметров модели
    for name, param in model.named_parameters():
        print(f"Parameter {name}, requires_grad: {param.requires_grad}")
        if not param.requires_grad:
            print(f"Warning: Parameter {name} does not require grad!")

    games = defaultdict(list)
    for sample in dataset['train']:
        games[sample['game_id']].append(sample)

    if max_games is not None:
        game_ids = list(games.keys())[:max_games]
        games = {gid: games[gid] for gid in game_ids}

    total_games = len(games)
    print(f"Total games to process: {total_games}")

    action_counts = defaultdict(int)
    invalid_samples = 0

    epochs = 10
    for epoch in range(epochs):
        start_time = time.time()
        total_loss = 0.0
        num_samples = 0
        games_processed = 0

        for game_id, snapshots in games.items():
            print(f"Processing game {game_id}...")
            snapshots = sorted(snapshots, key=lambda x: json.loads(x['snapshot'])['timestamp'])

            try:
                my_id = json.loads(snapshots[0]['snapshot'])['players'][0]['id']
            except (KeyError, IndexError):
                print(f"Skipping game {game_id}: invalid player data")
                continue

            for i in range(len(snapshots) - 1):
                try:
                    state = encode_state(snapshots[i], my_id, device=device)
                    print(f"Snapshot {i}, state requires_grad: {state.requires_grad}")

                    # Проверка на nan/inf в state
                    if torch.isnan(state).any() or torch.isinf(state).any():
                        print(f"Invalid values in state for snapshot {i} in game {game_id}")
                        continue

                    action = get_action(snapshots[i], snapshots[i + 1], my_id)

                    if action['type'] == 'invalid':
                        invalid_samples += 1
                        continue

                    if action['type'] not in ['attack', 'defend', 'state', 'wait']:
                        print(f"Unknown action type: {action['type']}")
                        continue

                    action_counts[action['type']] += 1

                    # Прямой проход через модель
                    action_logits, card_logits, state_logits = model(state.unsqueeze(0))

                    # Проверка grad_fn
                    print(f"action_logits grad_fn: {action_logits.grad_fn}")
                    print(f"card_logits grad_fn: {card_logits.grad_fn}")
                    print(f"state_logits grad_fn: {state_logits.grad_fn}")

                    loss = 0.0
                    if action['type'] == 'attack':
                        action_target = torch.tensor([0], dtype=torch.long, requires_grad=False, device=device)
                        card_target = torch.tensor([action['card_idx']], dtype=torch.long, requires_grad=False, device=device)
                        loss += action_criterion(action_logits, action_target)
                        loss += card_criterion(card_logits, card_target)
                    elif action['type'] == 'defend':
                        action_target = torch.tensor([1], dtype=torch.long, requires_grad=False, device=device)
                        card_target = torch.tensor([action['card_idx']], dtype=torch.long, requires_grad=False, device=device)
                        loss += action_criterion(action_logits, action_target)
                        loss += card_criterion(card_logits, card_target)
                    elif action['type'] == 'state':
                        action_target = torch.tensor([2], dtype=torch.long, requires_grad=False, device=device)
                        state_target = torch.tensor([action['state_idx']], dtype=torch.long, requires_grad=False, device=device)
                        loss += action_criterion(action_logits, action_target)
                        loss += state_criterion(state_logits, state_target)
                    else:
                        action_target = torch.tensor([3], dtype=torch.long, requires_grad=False, device=device)
                        loss += action_criterion(action_logits, action_target)

                    # Проверка на nan/inf в loss
                    if torch.isnan(loss) or torch.isinf(loss):
                        print(f"Loss is invalid: {loss}")
                        continue

                    optimizer.zero_grad()
                    loss.backward()
                    optimizer.step()

                    total_loss += loss.item()
                    num_samples += 1

                except Exception as e:
                    print(f"Error processing snapshot {i} in game {game_id}: {e}")
                    continue

            games_processed += 1
            if games_processed % 10 == 0:
                print(f"Epoch {epoch + 1}: Processed {games_processed}/{total_games} games ({games_processed/total_games*100:.1f}%)")

        elapsed_time = time.time() - start_time
        if num_samples > 0:
            print(f"Epoch {epoch + 1}, Loss: {total_loss / num_samples:.4f}, Samples: {num_samples}, Time: {elapsed_time:.2f}s")
        else:
            print(f"Epoch {epoch + 1}: No valid samples processed")

        print(f"Action distribution: {dict(action_counts)}")
        print(f"Invalid samples skipped: {invalid_samples}")

        checkpoint_path = f"durak_checkpoint_epoch_{epoch + 1}.pth"
        torch.save(model.state_dict(), checkpoint_path)
        print(f"Checkpoint saved to {checkpoint_path}")

    print("Saving final model...")
    torch.save(model.state_dict(), "durak_model.pth")
    print("Model weights saved to durak_model.pth")

    return model

# Предсказание действия
def predict_action(model, snapshot, my_id, device='cpu'):
    model.eval()
    with torch.no_grad():
        state = encode_state(snapshot, my_id, device=device)
        action_logits, card_logits, state_logits = model(state.unsqueeze(0))

        print(f"action_logits: {action_logits}")

        action_idx = torch.argmax(action_logits, dim=1).item()
        action_map = {0: 'attack', 1: 'defend', 2: 'state', 3: 'wait'}
        action_type = action_map[action_idx]

        if action_type == 'attack' or action_type == 'defend':
            card_idx = torch.argmax(card_logits, dim=1).item()
            ranks = {0: '9', 1: '10', 2: '11', 3: '12', 4: '13', 5: '14'}
            suits = {0: 'S', 1: 'C', 2: 'D', 3: 'H'}
            card = f"{ranks[card_idx // 4]}{suits[card_idx % 4]}"
            return {"type": action_type, "move": card}
        elif action_type == 'state':
            state_idx = torch.argmax(state_logits, dim=1).item()
            state_map = {0: 'bat', 1: 'pass', 2: 'take'}
            return {"type": "state", "state": state_map[state_idx]}
        else:
            return {"type": "wait"}

# Загрузка модели
def load_model(model_path="durak_model.pth", device='cpu'):
    model = DurakNet().to(device)
    if os.path.exists(model_path):
        model.load_state_dict(torch.load(model_path, map_location=device))
        model.eval()
        print(f"Model weights loaded from {model_path}")
        return model
    else:
        print(f"Model file {model_path} not found")
        return None

if __name__ == "__main__":
    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    print(f"Using device: {device}")

    model = train_model(max_games=100, device=device)

    print("Testing predictions...")
    dataset = load_dataset("neuronetties/durak")
    for i in range(3):
        sample = dataset['train'][i]
        my_id = json.loads(sample['snapshot'])['players'][0]['id']
        action = predict_action(model, sample, my_id, device=device)
        print(f"Sample {i}: Predicted action: {action}")

    loaded_model = load_model("durak_model.pth", device=device)
    if loaded_model:
        action = predict_action(loaded_model, dataset['train'][0], my_id, device=device)
        print(f"Loaded model prediction: {action}")
# Out:
# Using device: cpu
# Loading dataset...
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/321 [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/18.5M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/292962 [00:00<?, ? examples/s]
# Выходные данные были обрезаны до нескольких последних строк (5000).
# Snapshot 25, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# Snapshot 26, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# Snapshot 27, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# Snapshot 28, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# Snapshot 29, state requires_grad: True
# Detected transfer: 11C matches 11H
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# Snapshot 30, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# Snapshot 31, state requires_grad: True
# Detected transfer: 11S matches 11C
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# Snapshot 32, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# Snapshot 33, state requires_grad: True
# Detected transfer: 11D matches 11S
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# Snapshot 34, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# Snapshot 35, state requires_grad: True
# State change detected: attack -> bat
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# Snapshot 36, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# Snapshot 37, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# Processing game 5ea54469-e784-4eaa-8dc4-763274e2955f...
# Snapshot 0, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# Snapshot 1, state requires_grad: True
# State change detected: defend -> take
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# Snapshot 2, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# Snapshot 3, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# Snapshot 4, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# Snapshot 5, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# Snapshot 6, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# Snapshot 7, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# Snapshot 8, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# Snapshot 9, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# Snapshot 10, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# Snapshot 11, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# Snapshot 12, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# Snapshot 13, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# Snapshot 14, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# Snapshot 15, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# Snapshot 16, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# Snapshot 17, state requires_grad: True
# State change detected: attack -> pass
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# Snapshot 18, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# Snapshot 19, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# Snapshot 20, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# Snapshot 21, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# Snapshot 22, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# Snapshot 23, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# Snapshot 24, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# Snapshot 25, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6f0887cd0>
# Snapshot 26, state requires_grad: True
# State change detected: defend -> take
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# Snapshot 27, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# Snapshot 28, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# Snapshot 29, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# Snapshot 30, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# Snapshot 31, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# Snapshot 32, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# Snapshot 33, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# Snapshot 34, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# Snapshot 35, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# Snapshot 36, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# Snapshot 37, state requires_grad: True
# Detected transfer: 9D matches 9S
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# Snapshot 38, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# Snapshot 39, state requires_grad: True
# Detected transfer: 9C matches 9D
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# Snapshot 40, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# Snapshot 41, state requires_grad: True
# State change detected: attack -> bat
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# Snapshot 42, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# Snapshot 43, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# Snapshot 44, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# Processing game bbb08c33-6eff-4118-86d7-2588c4f0ccae...
# Snapshot 0, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# Snapshot 1, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# Snapshot 2, state requires_grad: True
# Detected transfer: 9H matches 9S
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# Snapshot 3, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# Snapshot 4, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# Snapshot 5, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# Snapshot 6, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# Snapshot 7, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# Snapshot 8, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# Snapshot 9, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# Snapshot 10, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# Snapshot 11, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# Snapshot 12, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# Snapshot 13, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# Snapshot 14, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# Snapshot 15, state requires_grad: True
# State change detected: defend -> take
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# Snapshot 16, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# Snapshot 17, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# Snapshot 18, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# Snapshot 19, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# Snapshot 20, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# Snapshot 21, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# Snapshot 22, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# Snapshot 23, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# Snapshot 24, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# Snapshot 25, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# Snapshot 26, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# Snapshot 27, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# Snapshot 28, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# Snapshot 29, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# Snapshot 30, state requires_grad: True
# Detected transfer: 13H matches 13D
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# Snapshot 31, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# Snapshot 32, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# Snapshot 33, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# Snapshot 34, state requires_grad: True
# State change detected: attack -> bat
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# Snapshot 35, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# Snapshot 36, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# Snapshot 37, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# Snapshot 38, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# Snapshot 39, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# Snapshot 40, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# Snapshot 41, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# Snapshot 42, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# Processing game a3a377a6-9dfd-47e4-9417-783c62cad026...
# Snapshot 0, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# Snapshot 1, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# Snapshot 2, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# Snapshot 3, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# Snapshot 4, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# Snapshot 5, state requires_grad: True
# State change detected: defend -> take
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# Snapshot 6, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# Snapshot 7, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# Snapshot 8, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# Snapshot 9, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# Snapshot 10, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# Snapshot 11, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# Snapshot 12, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# Snapshot 13, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# Snapshot 14, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# Snapshot 15, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# Snapshot 16, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# Snapshot 17, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# Snapshot 18, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# Snapshot 19, state requires_grad: True
# State change detected: attack -> pass
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# Snapshot 20, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# Snapshot 21, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# Snapshot 22, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# Snapshot 23, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# Snapshot 24, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c910>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c910>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c910>
# Snapshot 25, state requires_grad: True
# State change detected: attack -> bat
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c910>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c910>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c910>
# Snapshot 26, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# Snapshot 27, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# Snapshot 28, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# Snapshot 29, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# Snapshot 30, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# Snapshot 31, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# Snapshot 32, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# Snapshot 33, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# Snapshot 34, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# Snapshot 35, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# Snapshot 36, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# Snapshot 37, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# Snapshot 38, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c910>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c910>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c910>
# Snapshot 39, state requires_grad: True
# State change detected: attack -> bat
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c910>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c910>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c910>
# Snapshot 40, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# Snapshot 41, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# Snapshot 42, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# Snapshot 43, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# Snapshot 44, state requires_grad: True
# State change detected: defend -> take
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# Snapshot 45, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c910>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c910>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c910>
# Snapshot 46, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c910>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c910>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c910>
# Snapshot 47, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c910>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c910>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c910>
# Snapshot 48, state requires_grad: True
# State change detected: defend -> take
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c910>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c910>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c910>
# Snapshot 49, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# Snapshot 50, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# Snapshot 51, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# Processing game f73aa4cd-12b0-4332-8a88-13bc054d43b5...
# Snapshot 0, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# Snapshot 1, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# Snapshot 2, state requires_grad: True
# State change detected: attack -> pass
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# Snapshot 3, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# Snapshot 4, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# Snapshot 5, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# Snapshot 6, state requires_grad: True
# State change detected: attack -> pass
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# Snapshot 7, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# Snapshot 8, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# Snapshot 9, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# Snapshot 10, state requires_grad: True
# State change detected: attack -> pass
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# Snapshot 11, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# Snapshot 12, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# Snapshot 13, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# Snapshot 14, state requires_grad: True
# State change detected: attack -> bat
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# Snapshot 15, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c880>
# Snapshot 16, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# Snapshot 17, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# Snapshot 18, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# Snapshot 19, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# Snapshot 20, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# Snapshot 21, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# Snapshot 22, state requires_grad: True
# State change detected: attack -> bat
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# Snapshot 23, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# Snapshot 24, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# Snapshot 25, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# Snapshot 26, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# Snapshot 27, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# Snapshot 28, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# Snapshot 29, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# Snapshot 30, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# Snapshot 31, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# Snapshot 32, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# Snapshot 33, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# Snapshot 34, state requires_grad: True
# State change detected: attack -> pass
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# Snapshot 35, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# Snapshot 36, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# Snapshot 37, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# Snapshot 38, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# Snapshot 39, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# Snapshot 40, state requires_grad: True
# State change detected: attack -> bat
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# Snapshot 41, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# Snapshot 42, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# Snapshot 43, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# Snapshot 44, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# Snapshot 45, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1ce50>
# ...
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# Snapshot 21, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f040>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f040>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f040>
# Snapshot 22, state requires_grad: True
# Detected transfer: 9S matches 9C
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f040>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f040>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f040>
# Snapshot 23, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c910>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c910>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c910>
# Snapshot 24, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c910>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c910>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c910>
# Snapshot 25, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c910>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c910>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c910>
# Snapshot 26, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c910>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c910>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c910>
# Snapshot 27, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f040>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f040>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f040>
# Snapshot 28, state requires_grad: True
# State change detected: attack -> bat
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f040>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f040>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f040>
# Snapshot 29, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c910>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c910>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c910>
# Snapshot 30, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c910>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c910>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c910>
# Snapshot 31, state requires_grad: True
# State change detected: defend -> take
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c910>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c910>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c910>
# Snapshot 32, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f040>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f040>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f040>
# Snapshot 33, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f040>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f040>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f040>
# Snapshot 34, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f040>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f040>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f040>
# Processing game f621615f-5b09-4bed-865c-4f65515c6e1b...
# Snapshot 0, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f040>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f040>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f040>
# Snapshot 1, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c100>
# Snapshot 2, state requires_grad: True
# Detected transfer: 12D matches 12C
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f010>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f010>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f010>
# Snapshot 3, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f040>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f040>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f040>
# Snapshot 4, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f040>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f040>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f040>
# Snapshot 5, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f010>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f010>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f010>
# Snapshot 6, state requires_grad: True
# Detected transfer: 14H matches 14C
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f010>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f010>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f010>
# Snapshot 7, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f040>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f040>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f040>
# Snapshot 8, state requires_grad: True
# State change detected: attack -> pass
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f040>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f040>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f040>
# Snapshot 9, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f010>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f010>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f010>
# Snapshot 10, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f010>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f010>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f010>
# Snapshot 11, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f040>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f040>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f040>
# Snapshot 12, state requires_grad: True
# State change detected: attack -> bat
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f040>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f040>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f040>
# Snapshot 13, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f010>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f010>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f010>
# Snapshot 14, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f010>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f010>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f010>
# Snapshot 15, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f010>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f010>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f010>
# Snapshot 16, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f010>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f010>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f010>
# Snapshot 17, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f010>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f010>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f010>
# Snapshot 18, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f010>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f010>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f010>
# Snapshot 19, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f010>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f010>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f010>
# Snapshot 20, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f010>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f010>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f010>
# Snapshot 21, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f040>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f040>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f040>
# Snapshot 22, state requires_grad: True
# State change detected: attack -> bat
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f040>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f040>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f040>
# Snapshot 23, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f010>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f010>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f010>
# Snapshot 24, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f010>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f010>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f010>
# Snapshot 25, state requires_grad: True
# Detected transfer: 12H matches 12D
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f010>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f010>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f010>
# Snapshot 26, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f040>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f040>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f040>
# Snapshot 27, state requires_grad: True
# State change detected: defend -> take
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f040>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f040>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1f040>
# Snapshot 28, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1cd90>
# Snapshot 29, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# Snapshot 30, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# Snapshot 31, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# Snapshot 32, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# Snapshot 33, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# Snapshot 34, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# Snapshot 35, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# Snapshot 36, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# Snapshot 37, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# Snapshot 38, state requires_grad: True
# Detected transfer: 12C matches 12D
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# Snapshot 39, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# Snapshot 40, state requires_grad: True
# Detected transfer: 12H matches 12C
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# Snapshot 41, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# Snapshot 42, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# Snapshot 43, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# Snapshot 44, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# Snapshot 45, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# Snapshot 46, state requires_grad: True
# State change detected: attack -> pass
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1c3d0>
# Snapshot 47, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# Snapshot 48, state requires_grad: True
# action_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# card_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# state_logits grad_fn: <AddmmBackward0 object at 0x7fe6c9e1fe20>
# Epoch 10: Processed 100/100 games (100.0%)
# Epoch 10, Loss: 0.4221, Samples: 4731, Time: 23.79s
# Action distribution: {'attack': 8900, 'wait': 32960, 'state': 5450}
# Invalid samples skipped: 0
# Checkpoint saved to durak_checkpoint_epoch_10.pth
# Saving final model...
# Model weights saved to durak_model.pth
# Testing predictions...
# action_logits: tensor([[  6.2217, -44.8036,  -7.4920,  -6.2623]])
# Sample 0: Predicted action: {'type': 'attack', 'move': '10D'}
# action_logits: tensor([[ -2.8293, -51.1464,  -1.5825,   2.1460]])
# Sample 1: Predicted action: {'type': 'wait'}
# action_logits: tensor([[ -2.4544, -72.2606,   1.5098, -11.6610]])
# Sample 2: Predicted action: {'type': 'state', 'state': 'bat'}
# Model weights loaded from durak_model.pth
# action_logits: tensor([[  6.2217, -44.8036,  -7.4920,  -6.2623]])
# Loaded model prediction: {'type': 'attack', 'move': '10D'}

# %%
import torch
import torch.nn as nn
import numpy as np
from datasets import load_dataset
from collections import defaultdict
import json
import os

# Модель нейросети (должна совпадать с той, что использовалась при обучении)
class DurakNet(nn.Module):
    def __init__(self, input_dim=128, hidden_dim=256, num_cards=24, num_actions=4):
        super(DurakNet, self).__init__()

        self.state_encoder = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim // 2),
            nn.ReLU()
        )

        self.action_head = nn.Linear(hidden_dim // 2, num_actions)
        self.card_head = nn.Linear(hidden_dim // 2, num_cards)
        self.state_head = nn.Linear(hidden_dim // 2, 3)

    def forward(self, state):
        encoded = self.state_encoder(state)
        action_logits = self.action_head(encoded)
        card_logits = self.card_head(encoded)
        state_logits = self.state_head(encoded)
        return action_logits, card_logits, state_logits

# Кодирование состояния
def encode_state(snapshot, my_id, device='cpu'):
    try:
        data = json.loads(snapshot['snapshot'])

        state = np.zeros(128, dtype=np.float32)

        trump = data['trump']
        suits = {'S': 0, 'C': 1, 'D': 2, 'H': 3}
        ranks = {'9': 0, '10': 1, '11': 2, '12': 3, '13': 4, '14': 5}
        trump_rank, trump_suit = trump[:-1], trump[-1]
        state[0 + suits[trump_suit]] = 1.0
        state[4 + ranks[trump_rank]] = 1.0

        for player in data['players']:
            if player['id'] == my_id:
                for card in player['hand']:
                    rank, suit = card[:-1], card[-1]
                    card_idx = ranks[rank] * 4 + suits[suit]
                    state[10 + card_idx] = 1.0

        for i, pair in enumerate(data['table'][:4]):
            attack_card = pair['attack_card']['card']
            rank, suit = attack_card[:-1], attack_card[-1]
            state[34 + i * 12 + ranks[rank]] = 1.0
            state[34 + i * 12 + 6 + suits[suit]] = 1.0
            if 'defend_card' in pair:
                defend_card = pair['defend_card']['card']
                rank, suit = defend_card[:-1], defend_card[-1]
                state[82 + i * 12 + ranks[rank]] = 1.0
                state[82 + i * 12 + 6 + suits[suit]] = 1.0

        state[114] = len(data['deck']) / 24.0

        for player in data['players']:
            if player['id'] == my_id:
                state_map = {'attack': 115, 'defend': 116, 'bat': 117, 'pass': 118, 'take': 119}
                if player['state'] in state_map:
                    state[state_map[player['state']]] = 1.0

        state[120] = data['game_rules']['game_type']

        tensor = torch.tensor(state, dtype=torch.float32, device=device, requires_grad=False)
        return tensor

    except Exception as e:
        print(f"Error in encode_state: {e}")
        return torch.zeros(128, dtype=torch.float32, device=device)

# Проверка, может ли defend_card побить attack_card
def can_beat(attack_card, defend_card, trump_suit):
    suits = {'S': 0, 'C': 1, 'D': 2, 'H': 3}
    ranks = {'9': 0, '10': 1, '11': 2, '12': 3, '13': 4, '14': 5}

    attack_rank, attack_suit = attack_card[:-1], attack_card[-1]
    defend_rank, defend_suit = defend_card[:-1], defend_card[-1]

    attack_rank_idx = ranks[attack_rank]
    defend_rank_idx = ranks[defend_rank]
    attack_suit_idx = suits[attack_suit]
    defend_suit_idx = suits[defend_suit]
    trump_suit_idx = suits[trump_suit]

    if attack_suit_idx == defend_suit_idx:
        return defend_rank_idx > attack_rank_idx
    elif defend_suit_idx == trump_suit_idx and attack_suit_idx != trump_suit_idx:
        return True
    return False

# Извлечение реального действия (та же функция, что использовалась при обучении)
def get_action(prev_snapshot, curr_snapshot, my_id):
    try:
        prev_data = json.loads(prev_snapshot['snapshot'])
        curr_data = json.loads(curr_snapshot['snapshot'])

        ranks = {'9': 0, '10': 1, '11': 2, '12': 3, '13': 4, '14': 5}
        suits = {'S': 0, 'C': 1, 'D': 2, 'H': 3}
        trump_suit = curr_data['trump'][-1]
        game_type = curr_data['game_rules']['game_type']

        if len(curr_data['table']) > len(prev_data['table']):
            new_pair = curr_data['table'][-1]
            attack_card = new_pair['attack_card']['card']
            attack_user = new_pair['attack_card']['user_id']

            if attack_user == my_id:
                rank, suit = attack_card[:-1], attack_card[-1]
                card_idx = ranks[rank] * 4 + suits[suit]

                if game_type == 1 and prev_data['table']:
                    last_attack = prev_data['table'][-1]['attack_card']['card']
                    if last_attack[:-1] == attack_card[:-1]:
                        print(f"Detected transfer: {attack_card} matches {last_attack}")
                        return {'type': 'attack', 'card_idx': card_idx, 'card': attack_card}
                return {'type': 'attack', 'card_idx': card_idx, 'card': attack_card}

            if 'defend_card' in new_pair and new_pair['defend_card']['user_id'] == my_id:
                defend_card = new_pair['defend_card']['card']
                rank, suit = defend_card[:-1], defend_card[-1]
                card_idx = ranks[rank] * 4 + suits[suit]

                if not can_beat(attack_card, defend_card, trump_suit):
                    print(f"Invalid defend: {defend_card} cannot beat {attack_card}, trump={trump_suit}")
                    return {'type': 'invalid'}
                return {'type': 'defend', 'card_idx': card_idx, 'card': defend_card}

        for curr_p, prev_p in zip(curr_data['players'], prev_data['players']):
            if curr_p['id'] == my_id and curr_p['state'] != prev_p['state']:
                if curr_p['state'] in ['bat', 'pass', 'take']:
                    state_map = {'bat': 0, 'pass': 1, 'take': 2}
                    print(f"State change detected: {prev_p['state']} -> {curr_p['state']}")
                    return {'type': 'state', 'state_idx': state_map[curr_p['state']], 'state': curr_p['state']}

        if len(curr_data['table']) == 0 and len(prev_data['table']) > 0:
            for curr_p, prev_p in zip(curr_data['players'], prev_data['players']):
                if curr_p['id'] == my_id and curr_p['state'] == 'bat':
                    print("Detected 'bat' action: table cleared")
                    return {'type': 'state', 'state_idx': 0, 'state': 'bat'}

        return {'type': 'wait'}

    except Exception as e:
        print(f"Error in get_action: {e}")
        return {'type': 'invalid'}

# Предсказание действия моделью
def predict_action(model, snapshot, my_id, device='cpu'):
    model.eval()
    with torch.no_grad():
        state = encode_state(snapshot, my_id, device=device)
        action_logits, card_logits, state_logits = model(state.unsqueeze(0))

        print(f"action_logits: {action_logits}")

        action_idx = torch.argmax(action_logits, dim=1).item()
        action_map = {0: 'attack', 1: 'defend', 2: 'state', 3: 'wait'}
        action_type = action_map[action_idx]

        if action_type == 'attack' or action_type == 'defend':
            card_idx = torch.argmax(card_logits, dim=1).item()
            ranks = {0: '9', 1: '10', 2: '11', 3: '12', 4: '13', 5: '14'}
            suits = {0: 'S', 1: 'C', 2: 'D', 3: 'H'}
            card = f"{ranks[card_idx // 4]}{suits[card_idx % 4]}"
            return {"type": action_type, "move": card}
        elif action_type == 'state':
            state_idx = torch.argmax(state_logits, dim=1).item()
            state_map = {0: 'bat', 1: 'pass', 2: 'take'}
            return {"type": "state", "state": state_map[state_idx]}
        else:
            return {"type": "wait"}

# Загрузка модели
def load_model(model_path="durak_model.pth", device='cpu'):
    model = DurakNet().to(device)
    if os.path.exists(model_path):
        model.load_state_dict(torch.load(model_path, map_location=device))
        model.eval()
        print(f"Model weights loaded from {model_path}")
        return model
    else:
        print(f"Model file {model_path} not found")
        return None

# Тестирование модели
def test_model(max_games=None, device='cpu'):
    print("Loading dataset...")
    dataset = load_dataset("neuronetties/durak")
    print("Dataset loaded.")

    # Загрузка модели
    model = load_model("durak_model.pth", device=device)
    if model is None:
        print("Cannot proceed with testing: model not found.")
        return

    # Группировка снимков по играм
    games = defaultdict(list)
    for sample in dataset['train']:
        games[sample['game_id']].append(sample)

    if max_games is not None:
        game_ids = list(games.keys())[:max_games]
        games = {gid: games[gid] for gid in game_ids}

    total_games = len(games)
    print(f"Total games to test: {total_games}")

    # Метрики
    total_samples = 0
    correct_action_type = 0
    correct_card = 0  # Для attack и defend
    correct_state = 0  # Для state
    invalid_samples = 0

    for game_id, snapshots in games.items():
        print(f"\nTesting game {game_id}...")
        snapshots = sorted(snapshots, key=lambda x: json.loads(x['snapshot'])['timestamp'])

        try:
            my_id = json.loads(snapshots[0]['snapshot'])['players'][0]['id']
        except (KeyError, IndexError):
            print(f"Skipping game {game_id}: invalid player data")
            continue

        for i in range(len(snapshots) - 1):
            try:
                # Получаем реальное действие
                real_action = get_action(snapshots[i], snapshots[i + 1], my_id)

                if real_action['type'] == 'invalid':
                    invalid_samples += 1
                    continue

                if real_action['type'] not in ['attack', 'defend', 'state', 'wait']:
                    print(f"Unknown real action type: {real_action['type']}")
                    continue

                # Делаем предсказание
                predicted_action = predict_action(model, snapshots[i], my_id, device=device)

                total_samples += 1

                # Сравниваем тип действия
                print(f"\nSnapshot {i} in game {game_id}:")
                print(f"Real action: {real_action}")
                print(f"Predicted action: {predicted_action}")

                if real_action['type'] == predicted_action['type']:
                    correct_action_type += 1
                    print("Action type: CORRECT")

                    # Дополнительно сравниваем детали
                    if real_action['type'] in ['attack', 'defend']:
                        real_card = real_action.get('card', '')
                        predicted_card = predicted_action.get('move', '')
                        if real_card == predicted_card:
                            correct_card += 1
                            print("Card: CORRECT")
                        else:
                            print(f"Card: WRONG (Real: {real_card}, Predicted: {predicted_card})")

                    elif real_action['type'] == 'state':
                        real_state = real_action.get('state', '')
                        predicted_state = predicted_action.get('state', '')
                        if real_state == predicted_state:
                            correct_state += 1
                            print("State: CORRECT")
                        else:
                            print(f"State: WRONG (Real: {real_state}, Predicted: {predicted_state})")
                else:
                    print(f"Action type: WRONG (Real: {real_action['type']}, Predicted: {predicted_action['type']})")

            except Exception as e:
                print(f"Error testing snapshot {i} in game {game_id}: {e}")
                continue

    # Вывод метрик
    print("\n=== Testing Summary ===")
    print(f"Total samples tested: {total_samples}")
    print(f"Invalid samples skipped: {invalid_samples}")
    if total_samples > 0:
        action_accuracy = (correct_action_type / total_samples) * 100
        print(f"Action type accuracy: {action_accuracy:.2f}% ({correct_action_type}/{total_samples})")

        attack_defend_samples = sum(1 for action in dataset['train']
                                   if 'type' in get_action(action, dataset['train'][0], my_id)
                                   and get_action(action, dataset['train'][0], my_id)['type'] in ['attack', 'defend'])
        if attack_defend_samples > 0:
            card_accuracy = (correct_card / attack_defend_samples) * 100
            print(f"Card accuracy (attack/defend): {card_accuracy:.2f}% ({correct_card}/{attack_defend_samples})")

        state_samples = sum(1 for action in dataset['train']
                           if 'type' in get_action(action, dataset['train'][0], my_id)
                           and get_action(action, dataset['train'][0], my_id)['type'] == 'state')
        if state_samples > 0:
            state_accuracy = (correct_state / state_samples) * 100
            print(f"State accuracy (state actions): {state_accuracy:.2f}% ({correct_state}/{state_samples})")
    else:
        print("No valid samples to evaluate.")

if __name__ == "__main__":
    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    print(f"Using device: {device}")

    # Тестируем на 10 играх для начала (можно увеличить или убрать max_games)
    test_model(max_games=10, device=device)
# Out:
# Using device: cpu
# Loading dataset...
# Dataset loaded.
# Model weights loaded from durak_model.pth
# Total games to test: 10
#
# Testing game 8219abbc-7ec9-48f5-b9be-63374c227d6d...
# action_logits: tensor([[  6.2217, -44.8036,  -7.4920,  -6.2623]])
#
# Snapshot 0 in game 8219abbc-7ec9-48f5-b9be-63374c227d6d:
# Real action: {'type': 'attack', 'card_idx': 6, 'card': '10D'}
# Predicted action: {'type': 'attack', 'move': '10D'}
# Action type: CORRECT
# Card: CORRECT
# action_logits: tensor([[ -2.8293, -51.1464,  -1.5825,   2.1460]])
#
# Snapshot 1 in game 8219abbc-7ec9-48f5-b9be-63374c227d6d:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# State change detected: attack -> bat
# action_logits: tensor([[ -2.4544, -72.2606,   1.5098, -11.6610]])
#
# Snapshot 2 in game 8219abbc-7ec9-48f5-b9be-63374c227d6d:
# Real action: {'type': 'state', 'state_idx': 0, 'state': 'bat'}
# Predicted action: {'type': 'state', 'state': 'bat'}
# Action type: CORRECT
# State: CORRECT
# action_logits: tensor([[ -101.8647, -1049.6792,   -87.7634,    25.8180]])
#
# Snapshot 3 in game 8219abbc-7ec9-48f5-b9be-63374c227d6d:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -18.9859, -205.0553,  -16.5186,    6.3173]])
#
# Snapshot 4 in game 8219abbc-7ec9-48f5-b9be-63374c227d6d:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[  -7.7504, -107.7080,   -6.2243,    2.6943]])
#
# Snapshot 5 in game 8219abbc-7ec9-48f5-b9be-63374c227d6d:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -41.6979, -403.5494,  -33.4741,   11.0963]])
#
# Snapshot 6 in game 8219abbc-7ec9-48f5-b9be-63374c227d6d:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -41.6979, -403.5494,  -33.4741,   11.0963]])
#
# Snapshot 7 in game 8219abbc-7ec9-48f5-b9be-63374c227d6d:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[  10.5696, -162.2404,  -17.2850,  -13.4059]])
#
# Snapshot 8 in game 8219abbc-7ec9-48f5-b9be-63374c227d6d:
# Real action: {'type': 'attack', 'card_idx': 2, 'card': '9D'}
# Predicted action: {'type': 'attack', 'move': '9D'}
# Action type: CORRECT
# Card: CORRECT
# action_logits: tensor([[ -0.9055, -78.9816,  -4.7072,   3.7153]])
#
# Snapshot 9 in game 8219abbc-7ec9-48f5-b9be-63374c227d6d:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[  0.9624, -56.0478,  -0.9875,  -7.0740]])
#
# Snapshot 10 in game 8219abbc-7ec9-48f5-b9be-63374c227d6d:
# Real action: {'type': 'attack', 'card_idx': 21, 'card': '14C'}
# Predicted action: {'type': 'attack', 'move': '13H'}
# Action type: CORRECT
# Card: WRONG (Real: 14C, Predicted: 13H)
# action_logits: tensor([[ -4.3286, -43.5784,  -0.6679,   1.7783]])
#
# Snapshot 11 in game 8219abbc-7ec9-48f5-b9be-63374c227d6d:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# State change detected: attack -> bat
# action_logits: tensor([[ -0.1721, -48.8895,   0.1238,  -7.1020]])
#
# Snapshot 12 in game 8219abbc-7ec9-48f5-b9be-63374c227d6d:
# Real action: {'type': 'state', 'state_idx': 0, 'state': 'bat'}
# Predicted action: {'type': 'state', 'state': 'bat'}
# Action type: CORRECT
# State: CORRECT
# action_logits: tensor([[ -115.1374, -1157.8302,   -92.8792,    24.1582]])
#
# Snapshot 13 in game 8219abbc-7ec9-48f5-b9be-63374c227d6d:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -21.3044, -301.1962,  -26.8512,    8.7427]])
#
# Snapshot 14 in game 8219abbc-7ec9-48f5-b9be-63374c227d6d:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[  -5.2478, -146.1766,   -9.5391,    5.2729]])
#
# Snapshot 15 in game 8219abbc-7ec9-48f5-b9be-63374c227d6d:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[  -0.3381, -114.6161,   -8.1598,    5.0056]])
#
# Snapshot 16 in game 8219abbc-7ec9-48f5-b9be-63374c227d6d:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -13.2231, -165.4877,   -8.6296,    3.9903]])
#
# Snapshot 17 in game 8219abbc-7ec9-48f5-b9be-63374c227d6d:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -25.9164, -280.7477,  -19.4117,    7.4265]])
#
# Snapshot 18 in game 8219abbc-7ec9-48f5-b9be-63374c227d6d:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -14.1783, -132.7171,   -4.2248,    2.7241]])
#
# Snapshot 19 in game 8219abbc-7ec9-48f5-b9be-63374c227d6d:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -24.8766, -215.4332,   -8.4030,    3.9048]])
#
# Snapshot 20 in game 8219abbc-7ec9-48f5-b9be-63374c227d6d:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -24.8766, -215.4332,   -8.4030,    3.9048]])
#
# Snapshot 21 in game 8219abbc-7ec9-48f5-b9be-63374c227d6d:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[   8.4045, -128.4808,  -12.4752,   -9.3578]])
#
# Snapshot 22 in game 8219abbc-7ec9-48f5-b9be-63374c227d6d:
# Real action: {'type': 'attack', 'card_idx': 3, 'card': '9H'}
# Predicted action: {'type': 'attack', 'move': '9H'}
# Action type: CORRECT
# Card: CORRECT
# action_logits: tensor([[ -1.1881, -74.3666,  -4.8788,   4.0212]])
#
# Snapshot 23 in game 8219abbc-7ec9-48f5-b9be-63374c227d6d:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# State change detected: attack -> bat
# action_logits: tensor([[ -0.9532, -54.6081,   0.8087,  -9.1665]])
#
# Snapshot 24 in game 8219abbc-7ec9-48f5-b9be-63374c227d6d:
# Real action: {'type': 'state', 'state_idx': 0, 'state': 'bat'}
# Predicted action: {'type': 'state', 'state': 'bat'}
# Action type: CORRECT
# State: CORRECT
# action_logits: tensor([[ -102.7875, -1038.5306,   -96.0540,    20.0363]])
#
# Snapshot 25 in game 8219abbc-7ec9-48f5-b9be-63374c227d6d:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -14.0164, -123.5621,  -10.1868,    3.8926]])
#
# Snapshot 26 in game 8219abbc-7ec9-48f5-b9be-63374c227d6d:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -5.3806, -54.8700,  -2.0803,   1.2601]])
#
# Snapshot 27 in game 8219abbc-7ec9-48f5-b9be-63374c227d6d:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -34.9225, -298.4132,  -18.7927,    7.1533]])
#
# Snapshot 28 in game 8219abbc-7ec9-48f5-b9be-63374c227d6d:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -34.9225, -298.4132,  -18.7927,    7.1533]])
#
# Snapshot 29 in game 8219abbc-7ec9-48f5-b9be-63374c227d6d:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[  4.4331, -71.8697,  -4.2902, -12.1134]])
#
# Snapshot 30 in game 8219abbc-7ec9-48f5-b9be-63374c227d6d:
# Real action: {'type': 'attack', 'card_idx': 20, 'card': '14S'}
# Predicted action: {'type': 'attack', 'move': '12D'}
# Action type: CORRECT
# Card: WRONG (Real: 14S, Predicted: 12D)
# action_logits: tensor([[ -2.3398, -38.7895,   0.0462,   0.5589]])
#
# Snapshot 31 in game 8219abbc-7ec9-48f5-b9be-63374c227d6d:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# State change detected: attack -> pass
# action_logits: tensor([[ -2.3398, -38.7895,   0.0462,   0.5589]])
#
# Snapshot 32 in game 8219abbc-7ec9-48f5-b9be-63374c227d6d:
# Real action: {'type': 'state', 'state_idx': 1, 'state': 'pass'}
# Predicted action: {'type': 'wait'}
# Action type: WRONG (Real: state, Predicted: wait)
# action_logits: tensor([[ -74.7218, -826.4955,  -53.2440,   20.8997]])
#
# Snapshot 33 in game 8219abbc-7ec9-48f5-b9be-63374c227d6d:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[  5.3540, -80.2478,  -6.3412, -11.2923]])
#
# Snapshot 34 in game 8219abbc-7ec9-48f5-b9be-63374c227d6d:
# Real action: {'type': 'attack', 'card_idx': 14, 'card': '12D'}
# Predicted action: {'type': 'attack', 'move': '12D'}
# Action type: CORRECT
# Card: CORRECT
#
# Testing game 57ab056d-8bce-4840-bac1-cce09a104d96...
# action_logits: tensor([[ -18.4338, -206.4856,  -20.4713,    5.0802]])
#
# Snapshot 0 in game 57ab056d-8bce-4840-bac1-cce09a104d96:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -3.0562, -74.7742,  -4.8275,   2.4265]])
#
# Snapshot 1 in game 57ab056d-8bce-4840-bac1-cce09a104d96:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -24.9243, -264.9183,  -19.9216,    6.7140]])
#
# Snapshot 2 in game 57ab056d-8bce-4840-bac1-cce09a104d96:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[  -5.3356, -104.3125,   -5.8232,    3.1789]])
#
# Snapshot 3 in game 57ab056d-8bce-4840-bac1-cce09a104d96:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[  -9.7415, -139.0276,   -5.8240,    4.6093]])
#
# Snapshot 4 in game 57ab056d-8bce-4840-bac1-cce09a104d96:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -2.2710, -70.3382,  -3.3634,   3.2060]])
#
# Snapshot 5 in game 57ab056d-8bce-4840-bac1-cce09a104d96:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -1.1209, -49.0010,  -2.1881,   1.7244]])
#
# Snapshot 6 in game 57ab056d-8bce-4840-bac1-cce09a104d96:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -1.1209, -49.0010,  -2.1881,   1.7244]])
#
# Snapshot 7 in game 57ab056d-8bce-4840-bac1-cce09a104d96:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[  9.9947, -85.9607, -11.3288, -14.5176]])
#
# Snapshot 8 in game 57ab056d-8bce-4840-bac1-cce09a104d96:
# Real action: {'type': 'attack', 'card_idx': 10, 'card': '11D'}
# Predicted action: {'type': 'attack', 'move': '11D'}
# Action type: CORRECT
# Card: CORRECT
# Detected transfer: 11S matches 11D
# action_logits: tensor([[ -0.6289, -80.3390,  -4.7959,   3.2833]])
#
# Snapshot 9 in game 57ab056d-8bce-4840-bac1-cce09a104d96:
# Real action: {'type': 'attack', 'card_idx': 8, 'card': '11S'}
# Predicted action: {'type': 'wait'}
# Action type: WRONG (Real: attack, Predicted: wait)
# action_logits: tensor([[ -3.0149, -78.9251,  -2.5898,   2.8054]])
#
# Snapshot 10 in game 57ab056d-8bce-4840-bac1-cce09a104d96:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -3.0144, -58.4784,  -1.6252,   1.9482]])
#
# Snapshot 11 in game 57ab056d-8bce-4840-bac1-cce09a104d96:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# State change detected: attack -> bat
# action_logits: tensor([[ -0.3460, -57.6433,   1.1503, -12.3067]])
#
# Snapshot 12 in game 57ab056d-8bce-4840-bac1-cce09a104d96:
# Real action: {'type': 'state', 'state_idx': 0, 'state': 'bat'}
# Predicted action: {'type': 'state', 'state': 'bat'}
# Action type: CORRECT
# State: CORRECT
# action_logits: tensor([[ -126.9138, -1293.1620,  -115.3876,    27.0209]])
#
# Snapshot 13 in game 57ab056d-8bce-4840-bac1-cce09a104d96:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -27.9144, -287.5333,  -30.8076,    7.4424]])
#
# Snapshot 14 in game 57ab056d-8bce-4840-bac1-cce09a104d96:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -3.1410, -55.8672,  -4.2560,   0.4008]])
#
# Snapshot 15 in game 57ab056d-8bce-4840-bac1-cce09a104d96:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -1.5900, -62.9679,  -4.3817,   0.3288]])
#
# Snapshot 16 in game 57ab056d-8bce-4840-bac1-cce09a104d96:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -42.1130, -382.6376,  -34.9841,    8.3456]])
#
# Snapshot 17 in game 57ab056d-8bce-4840-bac1-cce09a104d96:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -56.5660, -537.6194,  -51.6146,   11.7263]])
#
# Snapshot 18 in game 57ab056d-8bce-4840-bac1-cce09a104d96:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -21.1624, -187.4776,  -12.9890,    2.6377]])
#
# Snapshot 19 in game 57ab056d-8bce-4840-bac1-cce09a104d96:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -57.2322, -555.7833,  -53.0514,   13.5499]])
#
# Snapshot 20 in game 57ab056d-8bce-4840-bac1-cce09a104d96:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -57.2322, -555.7833,  -53.0514,   13.5499]])
#
# Snapshot 21 in game 57ab056d-8bce-4840-bac1-cce09a104d96:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[  11.0571, -105.9131,  -13.3601,  -10.0976]])
#
# Snapshot 22 in game 57ab056d-8bce-4840-bac1-cce09a104d96:
# Real action: {'type': 'attack', 'card_idx': 2, 'card': '9D'}
# Predicted action: {'type': 'attack', 'move': '9H'}
# Action type: CORRECT
# Card: WRONG (Real: 9D, Predicted: 9H)
# Detected transfer: 9H matches 9D
# action_logits: tensor([[  2.9800, -87.6733,  -6.6550,   1.1752]])
#
# Snapshot 23 in game 57ab056d-8bce-4840-bac1-cce09a104d96:
# Real action: {'type': 'attack', 'card_idx': 3, 'card': '9H'}
# Predicted action: {'type': 'attack', 'move': '9H'}
# Action type: CORRECT
# Card: CORRECT
# action_logits: tensor([[ -4.6526, -72.7313,  -1.4376,   2.4374]])
#
# Snapshot 24 in game 57ab056d-8bce-4840-bac1-cce09a104d96:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -4.4384, -64.9967,  -2.1037,   3.0156]])
#
# Snapshot 25 in game 57ab056d-8bce-4840-bac1-cce09a104d96:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# State change detected: attack -> bat
# action_logits: tensor([[ -2.0759, -62.9897,   2.1220, -12.0611]])
#
# Snapshot 26 in game 57ab056d-8bce-4840-bac1-cce09a104d96:
# Real action: {'type': 'state', 'state_idx': 0, 'state': 'bat'}
# Predicted action: {'type': 'state', 'state': 'bat'}
# Action type: CORRECT
# State: CORRECT
# action_logits: tensor([[ -130.3459, -1233.4147,  -103.0599,    29.5085]])
#
# Snapshot 27 in game 57ab056d-8bce-4840-bac1-cce09a104d96:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -9.4687, -78.2733,  -5.3770,   1.8649]])
#
# Snapshot 28 in game 57ab056d-8bce-4840-bac1-cce09a104d96:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -8.0280, -55.9405,  -0.2844,  -0.4453]])
#
# Snapshot 29 in game 57ab056d-8bce-4840-bac1-cce09a104d96:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'state', 'state': 'take'}
# Action type: WRONG (Real: wait, Predicted: state)
#
# Testing game b31e9141-5e2b-43e8-9a66-cd21b87f911e...
# action_logits: tensor([[ -18.5596, -202.3454,  -19.9654,    4.8970]])
#
# Snapshot 0 in game b31e9141-5e2b-43e8-9a66-cd21b87f911e:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[  -3.7541, -100.2602,   -6.6195,    3.9604]])
#
# Snapshot 1 in game b31e9141-5e2b-43e8-9a66-cd21b87f911e:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -33.6430, -351.0995,  -31.1331,   10.7540]])
#
# Snapshot 2 in game b31e9141-5e2b-43e8-9a66-cd21b87f911e:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -13.0458, -171.8503,   -9.7949,    5.4854]])
#
# Snapshot 3 in game b31e9141-5e2b-43e8-9a66-cd21b87f911e:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -23.8043, -298.8793,  -25.4631,   11.0641]])
#
# Snapshot 4 in game b31e9141-5e2b-43e8-9a66-cd21b87f911e:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -23.8043, -298.8793,  -25.4631,   11.0641]])
#
# Snapshot 5 in game b31e9141-5e2b-43e8-9a66-cd21b87f911e:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ 10.3738, -88.0510, -10.5228, -10.2009]])
#
# Snapshot 6 in game b31e9141-5e2b-43e8-9a66-cd21b87f911e:
# Real action: {'type': 'attack', 'card_idx': 2, 'card': '9D'}
# Predicted action: {'type': 'attack', 'move': '9D'}
# Action type: CORRECT
# Card: CORRECT
# action_logits: tensor([[ -1.0091, -88.8265,  -5.7777,   4.9359]])
#
# Snapshot 7 in game b31e9141-5e2b-43e8-9a66-cd21b87f911e:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# State change detected: attack -> bat
# action_logits: tensor([[   1.9598, -115.2655,   -0.5810,  -16.1783]])
#
# Snapshot 8 in game b31e9141-5e2b-43e8-9a66-cd21b87f911e:
# Real action: {'type': 'state', 'state_idx': 0, 'state': 'bat'}
# Predicted action: {'type': 'attack', 'move': '12C'}
# Action type: WRONG (Real: state, Predicted: attack)
# action_logits: tensor([[ -105.7148, -1133.7124,   -97.4370,    23.0103]])
#
# Snapshot 9 in game b31e9141-5e2b-43e8-9a66-cd21b87f911e:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[  -7.6961, -102.6331,   -9.0653,    3.7461]])
#
# Snapshot 10 in game b31e9141-5e2b-43e8-9a66-cd21b87f911e:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# Detected transfer: 13D matches 13C
# action_logits: tensor([[  1.5701, -35.5015,  -1.3682,  -0.1247]])
#
# Snapshot 11 in game b31e9141-5e2b-43e8-9a66-cd21b87f911e:
# Real action: {'type': 'attack', 'card_idx': 18, 'card': '13D'}
# Predicted action: {'type': 'attack', 'move': '11C'}
# Action type: CORRECT
# Card: WRONG (Real: 13D, Predicted: 11C)
# action_logits: tensor([[ -3.0218, -64.4161,  -0.2554,   1.1641]])
#
# Snapshot 12 in game b31e9141-5e2b-43e8-9a66-cd21b87f911e:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# State change detected: defend -> take
# action_logits: tensor([[ -3.0214, -71.4813,   0.5244,  -2.1317]])
#
# Snapshot 13 in game b31e9141-5e2b-43e8-9a66-cd21b87f911e:
# Real action: {'type': 'state', 'state_idx': 2, 'state': 'take'}
# Predicted action: {'type': 'state', 'state': 'take'}
# Action type: CORRECT
# State: CORRECT
# action_logits: tensor([[ -26.1964, -274.3811,   -5.6045,    8.9094]])
#
# Snapshot 14 in game b31e9141-5e2b-43e8-9a66-cd21b87f911e:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -26.1964, -274.3811,   -5.6045,    8.9094]])
#
# Snapshot 15 in game b31e9141-5e2b-43e8-9a66-cd21b87f911e:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[  -7.3724, -122.0628,  -10.1763,    4.8067]])
#
# Snapshot 16 in game b31e9141-5e2b-43e8-9a66-cd21b87f911e:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[  0.6805, -72.5181,  -5.3800,   2.6261]])
#
# Snapshot 17 in game b31e9141-5e2b-43e8-9a66-cd21b87f911e:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -21.8956, -197.5462,  -13.4910,    5.3161]])
#
# Snapshot 18 in game b31e9141-5e2b-43e8-9a66-cd21b87f911e:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -21.8956, -197.5462,  -13.4910,    5.3161]])
#
# Snapshot 19 in game b31e9141-5e2b-43e8-9a66-cd21b87f911e:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[  5.6210, -76.3598,  -6.3744,  -8.4191]])
#
# Snapshot 20 in game b31e9141-5e2b-43e8-9a66-cd21b87f911e:
# Real action: {'type': 'attack', 'card_idx': 19, 'card': '13H'}
# Predicted action: {'type': 'attack', 'move': '13C'}
# Action type: CORRECT
# Card: WRONG (Real: 13H, Predicted: 13C)
# action_logits: tensor([[  0.9319, -62.4418,  -4.0946,   2.5835]])
#
# Snapshot 21 in game b31e9141-5e2b-43e8-9a66-cd21b87f911e:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# Detected transfer: 13D matches 13H
# action_logits: tensor([[  4.0310, -54.2397,  -4.0113,  -6.2608]])
#
# Snapshot 22 in game b31e9141-5e2b-43e8-9a66-cd21b87f911e:
# Real action: {'type': 'attack', 'card_idx': 18, 'card': '13D'}
# Predicted action: {'type': 'attack', 'move': '13C'}
# Action type: CORRECT
# Card: WRONG (Real: 13D, Predicted: 13C)
# action_logits: tensor([[ -0.5387, -53.3521,  -1.5832,   1.3564]])
#
# Snapshot 23 in game b31e9141-5e2b-43e8-9a66-cd21b87f911e:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# Detected transfer: 13C matches 13D
# action_logits: tensor([[  4.5761, -64.7655,  -5.2263,  -4.4306]])
#
# Snapshot 24 in game b31e9141-5e2b-43e8-9a66-cd21b87f911e:
# Real action: {'type': 'attack', 'card_idx': 17, 'card': '13C'}
# Predicted action: {'type': 'attack', 'move': '13C'}
# Action type: CORRECT
# Card: CORRECT
# action_logits: tensor([[ -0.4656, -58.7919,  -2.2184,   1.7902]])
#
# Snapshot 25 in game b31e9141-5e2b-43e8-9a66-cd21b87f911e:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[  2.1440, -60.2704,  -2.5669,  -2.8739]])
#
# Snapshot 26 in game b31e9141-5e2b-43e8-9a66-cd21b87f911e:
# Real action: {'type': 'attack', 'card_idx': 21, 'card': '14C'}
# Predicted action: {'type': 'attack', 'move': '14C'}
# Action type: CORRECT
# Card: CORRECT
# action_logits: tensor([[-3.7549e-02, -5.4633e+01, -1.9501e+00,  1.3327e+00]])
#
# Snapshot 27 in game b31e9141-5e2b-43e8-9a66-cd21b87f911e:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[  0.9508, -50.7027,  -1.9260,   0.9998]])
#
# Snapshot 28 in game b31e9141-5e2b-43e8-9a66-cd21b87f911e:
# Real action: {'type': 'attack', 'card_idx': 9, 'card': '11C'}
# Predicted action: {'type': 'wait'}
# Action type: WRONG (Real: attack, Predicted: wait)
# Detected transfer: 11D matches 11C
# action_logits: tensor([[  0.6388, -39.1506,  -1.0300,   0.6179]])
#
# Snapshot 29 in game b31e9141-5e2b-43e8-9a66-cd21b87f911e:
# Real action: {'type': 'attack', 'card_idx': 10, 'card': '11D'}
# Predicted action: {'type': 'attack', 'move': '14S'}
# Action type: CORRECT
# Card: WRONG (Real: 11D, Predicted: 14S)
# State change detected: attack -> pass
# action_logits: tensor([[-2.2054e-02, -3.1835e+01, -3.6331e-01,  4.5705e-01]])
#
# Snapshot 30 in game b31e9141-5e2b-43e8-9a66-cd21b87f911e:
# Real action: {'type': 'state', 'state_idx': 1, 'state': 'pass'}
# Predicted action: {'type': 'wait'}
# Action type: WRONG (Real: state, Predicted: wait)
# action_logits: tensor([[ -18.6088, -184.7016,   -3.8003,    4.6616]])
#
# Snapshot 31 in game b31e9141-5e2b-43e8-9a66-cd21b87f911e:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[  6.3093, -96.0108,  -8.0367,  -7.1013]])
#
# Snapshot 32 in game b31e9141-5e2b-43e8-9a66-cd21b87f911e:
# Real action: {'type': 'attack', 'card_idx': 3, 'card': '9H'}
# Predicted action: {'type': 'attack', 'move': '9H'}
# Action type: CORRECT
# Card: CORRECT
# action_logits: tensor([[ -1.2433, -80.0333,  -5.1505,   4.3767]])
#
# Snapshot 33 in game b31e9141-5e2b-43e8-9a66-cd21b87f911e:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[  2.8793, -99.1598,  -3.1130, -12.8054]])
#
# Snapshot 34 in game b31e9141-5e2b-43e8-9a66-cd21b87f911e:
# Real action: {'type': 'attack', 'card_idx': 13, 'card': '12C'}
# Predicted action: {'type': 'attack', 'move': '12C'}
# Action type: CORRECT
# Card: CORRECT
# action_logits: tensor([[ -3.1203, -60.9360,  -2.2999,   0.9942]])
#
# Snapshot 35 in game b31e9141-5e2b-43e8-9a66-cd21b87f911e:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# State change detected: attack -> bat
# action_logits: tensor([[ -1.9195, -98.5901,   2.1399, -18.8726]])
#
# Snapshot 36 in game b31e9141-5e2b-43e8-9a66-cd21b87f911e:
# Real action: {'type': 'state', 'state_idx': 0, 'state': 'bat'}
# Predicted action: {'type': 'state', 'state': 'bat'}
# Action type: CORRECT
# State: CORRECT
# action_logits: tensor([[ -177.4562, -1747.3167,  -151.0571,    35.0273]])
#
# Snapshot 37 in game b31e9141-5e2b-43e8-9a66-cd21b87f911e:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -8.9792, -82.4550,  -7.0942,   2.5430]])
#
# Snapshot 38 in game b31e9141-5e2b-43e8-9a66-cd21b87f911e:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -1.5078, -34.8823,  -0.3469,  -0.7915]])
#
# Snapshot 39 in game b31e9141-5e2b-43e8-9a66-cd21b87f911e:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'state', 'state': 'take'}
# Action type: WRONG (Real: wait, Predicted: state)
# Detected transfer: 14S matches 14H
# action_logits: tensor([[ -1.4537, -44.3645,   0.4039,  -1.7516]])
#
# Snapshot 40 in game b31e9141-5e2b-43e8-9a66-cd21b87f911e:
# Real action: {'type': 'attack', 'card_idx': 20, 'card': '14S'}
# Predicted action: {'type': 'state', 'state': 'take'}
# Action type: WRONG (Real: attack, Predicted: state)
# action_logits: tensor([[ -3.7996, -62.7903,   1.1515,  -0.2188]])
#
# Snapshot 41 in game b31e9141-5e2b-43e8-9a66-cd21b87f911e:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'state', 'state': 'pass'}
# Action type: WRONG (Real: wait, Predicted: state)
# State change detected: attack -> pass
# action_logits: tensor([[ -3.7996, -62.7903,   1.1515,  -0.2188]])
#
# Snapshot 42 in game b31e9141-5e2b-43e8-9a66-cd21b87f911e:
# Real action: {'type': 'state', 'state_idx': 1, 'state': 'pass'}
# Predicted action: {'type': 'state', 'state': 'pass'}
# Action type: CORRECT
# State: CORRECT
# action_logits: tensor([[ -48.5153, -549.4003,  -19.5698,   15.1502]])
#
# Snapshot 43 in game b31e9141-5e2b-43e8-9a66-cd21b87f911e:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[  6.7234, -69.2321,  -7.9270, -11.1708]])
#
# Snapshot 44 in game b31e9141-5e2b-43e8-9a66-cd21b87f911e:
# Real action: {'type': 'attack', 'card_idx': 11, 'card': '11H'}
# Predicted action: {'type': 'attack', 'move': '11H'}
# Action type: CORRECT
# Card: CORRECT
#
# Testing game 9370d26c-f055-4aeb-baa1-13d7aed19098...
# action_logits: tensor([[ -13.2454, -138.2733,  -14.2966,    3.7724]])
#
# Snapshot 0 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# Detected transfer: 11C matches 11D
# action_logits: tensor([[  2.2901, -41.1316,  -1.7319,  -0.3944]])
#
# Snapshot 1 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'attack', 'card_idx': 9, 'card': '11C'}
# Predicted action: {'type': 'attack', 'move': '11C'}
# Action type: CORRECT
# Card: CORRECT
# action_logits: tensor([[ -0.3151, -83.6438,  -3.5078,   1.9825]])
#
# Snapshot 2 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ 5.1993e-02, -6.2310e+01, -3.5452e+00,  2.2717e+00]])
#
# Snapshot 3 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[  4.9441, -61.3225,  -1.9464,  -9.7291]])
#
# Snapshot 4 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'attack', 'card_idx': 13, 'card': '12C'}
# Predicted action: {'type': 'attack', 'move': '12C'}
# Action type: CORRECT
# Card: CORRECT
# action_logits: tensor([[ -5.6059, -45.9792,   0.3810,   0.8111]])
#
# Snapshot 5 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# State change detected: attack -> pass
# action_logits: tensor([[ -5.6059, -45.9792,   0.3810,   0.8111]])
#
# Snapshot 6 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'state', 'state_idx': 1, 'state': 'pass'}
# Predicted action: {'type': 'wait'}
# Action type: WRONG (Real: state, Predicted: wait)
# action_logits: tensor([[ -123.4940, -1265.0048,   -86.6597,    26.1192]])
#
# Snapshot 7 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[  8.0295, -96.9884, -14.0179,  -5.3036]])
#
# Snapshot 8 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'attack', 'card_idx': 5, 'card': '10C'}
# Predicted action: {'type': 'attack', 'move': '10C'}
# Action type: CORRECT
# Card: CORRECT
# action_logits: tensor([[  1.4351, -84.8194,  -5.5355,   2.9474]])
#
# Snapshot 9 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# Detected transfer: 10H matches 10C
# action_logits: tensor([[  4.5920, -52.2656,  -6.2531,  -2.0616]])
#
# Snapshot 10 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'attack', 'card_idx': 7, 'card': '10H'}
# Predicted action: {'type': 'attack', 'move': '10H'}
# Action type: CORRECT
# Card: CORRECT
# action_logits: tensor([[ -0.7558, -57.1960,  -1.8731,   1.0227]])
#
# Snapshot 11 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# Detected transfer: 10D matches 10H
# action_logits: tensor([[  2.0962, -49.5644,  -4.2027,   0.3028]])
#
# Snapshot 12 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'attack', 'card_idx': 6, 'card': '10D'}
# Predicted action: {'type': 'attack', 'move': '10S'}
# Action type: CORRECT
# Card: WRONG (Real: 10D, Predicted: 10S)
# action_logits: tensor([[ -6.3782, -63.6723,  -0.6349,   1.9869]])
#
# Snapshot 13 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# State change detected: attack -> bat
# action_logits: tensor([[ -2.7964, -35.0607,  -0.7899,   0.3642]])
#
# Snapshot 14 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'state', 'state_idx': 0, 'state': 'bat'}
# Predicted action: {'type': 'wait'}
# Action type: WRONG (Real: state, Predicted: wait)
# action_logits: tensor([[ -86.0587, -796.0950,  -59.2664,   21.6339]])
#
# Snapshot 15 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -19.5855, -167.9851,  -16.7188,    3.3736]])
#
# Snapshot 16 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# State change detected: defend -> take
# action_logits: tensor([[ -1.7855, -29.8081,   0.3231,  -0.6472]])
#
# Snapshot 17 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'state', 'state_idx': 2, 'state': 'take'}
# Predicted action: {'type': 'state', 'state': 'take'}
# Action type: CORRECT
# State: CORRECT
# action_logits: tensor([[ -84.0081, -840.0134,  -64.0544,   17.7747]])
#
# Snapshot 18 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -75.2970, -785.7570,  -54.4013,   17.3034]])
#
# Snapshot 19 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -75.2970, -785.7570,  -54.4013,   17.3034]])
#
# Snapshot 20 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -19.9054, -209.1146,  -22.5424,    3.7537]])
#
# Snapshot 21 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# Detected transfer: 9D matches 9C
# action_logits: tensor([[  1.7469, -65.1308,  -6.6578,   1.7458]])
#
# Snapshot 22 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'attack', 'card_idx': 2, 'card': '9D'}
# Predicted action: {'type': 'attack', 'move': '9D'}
# Action type: CORRECT
# Card: CORRECT
# action_logits: tensor([[  -3.0738, -104.9178,   -4.8424,    4.5104]])
#
# Snapshot 23 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[  -3.2289, -119.5875,   -6.5854,    5.0895]])
#
# Snapshot 24 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -2.5997, -99.4289,  -5.2675,   4.3582]])
#
# Snapshot 25 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -6.5232, -72.9988,  -2.2254,   2.3695]])
#
# Snapshot 26 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[-10.7853, -82.3769,  -0.8186,   2.2668]])
#
# Snapshot 27 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[-10.6634, -74.9891,  -0.1557,   1.7317]])
#
# Snapshot 28 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[-12.1862, -68.6174,   0.5803,   1.0533]])
#
# Snapshot 29 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# State change detected: defend -> take
# action_logits: tensor([[-12.1862, -68.6174,   0.5803,   1.0533]])
#
# Snapshot 30 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'state', 'state_idx': 2, 'state': 'take'}
# Predicted action: {'type': 'wait'}
# Action type: WRONG (Real: state, Predicted: wait)
# action_logits: tensor([[ -38.8377, -318.5686,   -6.9015,    5.1883]])
#
# Snapshot 31 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -38.8377, -318.5686,   -6.9015,    5.1883]])
#
# Snapshot 32 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -42.1982, -448.0935,  -40.2955,    9.8145]])
#
# Snapshot 33 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -13.8083, -144.2991,   -8.0199,    3.3656]])
#
# Snapshot 34 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -85.7889, -824.3812,  -73.1770,   16.1777]])
#
# Snapshot 35 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -54.5946, -493.1196,  -34.7726,    9.6368]])
#
# Snapshot 36 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -90.3923, -872.3843,  -75.6388,   17.0042]])
#
# Snapshot 37 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -90.3923, -872.3843,  -75.6388,   17.0042]])
#
# Snapshot 38 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[   6.6333, -116.5978,  -10.2364,   -6.8611]])
#
# Snapshot 39 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'attack', 'card_idx': 3, 'card': '9H'}
# Predicted action: {'type': 'attack', 'move': '9H'}
# Action type: CORRECT
# Card: CORRECT
# action_logits: tensor([[ -0.7438, -79.8646,  -5.3560,   2.8600]])
#
# Snapshot 40 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# Detected transfer: 9D matches 9H
# action_logits: tensor([[   7.6316, -138.0445,  -10.8882,  -21.1101]])
#
# Snapshot 41 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'attack', 'card_idx': 2, 'card': '9D'}
# Predicted action: {'type': 'attack', 'move': '9C'}
# Action type: CORRECT
# Card: WRONG (Real: 9D, Predicted: 9C)
# action_logits: tensor([[  -1.3848, -100.4779,   -5.8628,    2.5020]])
#
# Snapshot 42 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[   8.2552, -149.6362,  -10.5935,  -19.1861]])
#
# Snapshot 43 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'attack', 'card_idx': 15, 'card': '12H'}
# Predicted action: {'type': 'attack', 'move': '12H'}
# Action type: CORRECT
# Card: CORRECT
# action_logits: tensor([[ -1.7184, -74.9743,  -1.8385,  -2.0972]])
#
# Snapshot 44 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'attack', 'move': '12C'}
# Action type: WRONG (Real: wait, Predicted: attack)
# action_logits: tensor([[   9.9303, -132.6429,   -8.1294,  -28.4657]])
#
# Snapshot 45 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'attack', 'card_idx': 11, 'card': '11H'}
# Predicted action: {'type': 'attack', 'move': '11H'}
# Action type: CORRECT
# Card: CORRECT
# State change detected: attack -> pass
# action_logits: tensor([[-1.5277e+00, -4.0603e+01, -3.6777e-02, -8.5254e-01]])
#
# Snapshot 46 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'state', 'state_idx': 1, 'state': 'pass'}
# Predicted action: {'type': 'state', 'state': 'pass'}
# Action type: CORRECT
# State: CORRECT
# action_logits: tensor([[ -145.1905, -1398.0348,  -115.5446,    26.3611]])
#
# Snapshot 47 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[   9.4180, -115.8801,   -9.3924,  -15.6738]])
#
# Snapshot 48 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'attack', 'card_idx': 14, 'card': '12D'}
# Predicted action: {'type': 'attack', 'move': '12D'}
# Action type: CORRECT
# Card: CORRECT
# action_logits: tensor([[ -1.5879, -70.5151,  -2.5415,   1.5865]])
#
# Snapshot 49 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# Detected transfer: 12C matches 12D
# action_logits: tensor([[   4.2995, -137.6482,   -4.2145,  -17.1646]])
#
# Snapshot 50 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'attack', 'card_idx': 13, 'card': '12C'}
# Predicted action: {'type': 'attack', 'move': '12C'}
# Action type: CORRECT
# Card: CORRECT
# action_logits: tensor([[ -12.9771, -121.4512,   -1.3420,   -2.7327]])
#
# Snapshot 51 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'state', 'state': 'bat'}
# Action type: WRONG (Real: wait, Predicted: state)
# State change detected: attack -> bat
# action_logits: tensor([[ -13.1019, -160.6761,    1.7489,  -16.6136]])
#
# Snapshot 52 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'state', 'state_idx': 0, 'state': 'bat'}
# Predicted action: {'type': 'state', 'state': 'bat'}
# Action type: CORRECT
# State: CORRECT
# action_logits: tensor([[ -224.5714, -2065.7727,  -170.0282,    42.9028]])
#
# Snapshot 53 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -31.2051, -259.5432,  -23.0441,    7.1452]])
#
# Snapshot 54 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -6.3990, -61.3344,  -2.3428,   0.5302]])
#
# Snapshot 55 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -32.2015, -263.4420,  -17.9924,    5.4840]])
#
# Snapshot 56 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# State change detected: defend -> take
# action_logits: tensor([[-11.7024, -77.7908,   0.8588,  -1.4284]])
#
# Snapshot 57 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'state', 'state_idx': 2, 'state': 'take'}
# Predicted action: {'type': 'state', 'state': 'take'}
# Action type: CORRECT
# State: CORRECT
# action_logits: tensor([[ -99.0161, -888.2120,  -61.1039,   17.7324]])
#
# Snapshot 58 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -99.0161, -888.2120,  -61.1039,   17.7324]])
#
# Snapshot 59 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -37.3696, -330.4036,  -31.4155,    7.4792]])
#
# Snapshot 60 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[-14.4474, -90.0289,  -3.2127,   0.9038]])
#
# Snapshot 61 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# State change detected: defend -> take
# action_logits: tensor([[-10.7111, -69.8047,   0.2482,  -0.6786]])
#
# Snapshot 62 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'state', 'state_idx': 2, 'state': 'take'}
# Predicted action: {'type': 'state', 'state': 'take'}
# Action type: CORRECT
# State: CORRECT
# action_logits: tensor([[ -139.5537, -1370.3619,   -98.8427,    27.7373]])
#
# Snapshot 63 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -139.5537, -1370.3619,   -98.8427,    27.7373]])
#
# Snapshot 64 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -42.7379, -388.1959,  -37.1729,    6.9312]])
#
# Snapshot 65 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -18.8970, -199.6707,  -15.8073,    2.2849]])
#
# Snapshot 66 in game 9370d26c-f055-4aeb-baa1-13d7aed19098:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
#
# Testing game 7f71f4d8-167c-40d7-81ae-bb88e718e87e...
# action_logits: tensor([[  5.8207, -61.1014,  -7.5108,  -7.1497]])
#
# Snapshot 0 in game 7f71f4d8-167c-40d7-81ae-bb88e718e87e:
# Real action: {'type': 'attack', 'card_idx': 17, 'card': '13C'}
# Predicted action: {'type': 'attack', 'move': '13C'}
# Action type: CORRECT
# Card: CORRECT
# action_logits: tensor([[ -0.9458, -31.2053,   0.0832,   0.2877]])
#
# Snapshot 1 in game 7f71f4d8-167c-40d7-81ae-bb88e718e87e:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# Detected transfer: 13H matches 13C
# action_logits: tensor([[ -0.9458, -31.2053,   0.0832,   0.2877]])
#
# Snapshot 2 in game 7f71f4d8-167c-40d7-81ae-bb88e718e87e:
# Real action: {'type': 'attack', 'card_idx': 19, 'card': '13H'}
# Predicted action: {'type': 'wait'}
# Action type: WRONG (Real: attack, Predicted: wait)
# State change detected: attack -> pass
# action_logits: tensor([[ -2.3821, -52.5567,   0.8766,  -0.2923]])
#
# Snapshot 3 in game 7f71f4d8-167c-40d7-81ae-bb88e718e87e:
# Real action: {'type': 'state', 'state_idx': 1, 'state': 'pass'}
# Predicted action: {'type': 'state', 'state': 'pass'}
# Action type: CORRECT
# State: CORRECT
# action_logits: tensor([[ -41.8063, -379.4506,  -13.9335,   10.4287]])
#
# Snapshot 4 in game 7f71f4d8-167c-40d7-81ae-bb88e718e87e:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[  7.5065, -70.8267,  -8.8733, -10.3879]])
#
# Snapshot 5 in game 7f71f4d8-167c-40d7-81ae-bb88e718e87e:
# Real action: {'type': 'attack', 'card_idx': 11, 'card': '11H'}
# Predicted action: {'type': 'attack', 'move': '11H'}
# Action type: CORRECT
# Card: CORRECT
# action_logits: tensor([[ -0.2237, -60.6582,  -3.2930,   2.0726]])
#
# Snapshot 6 in game 7f71f4d8-167c-40d7-81ae-bb88e718e87e:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# State change detected: defend -> take
# action_logits: tensor([[ -0.9939, -38.4536,  -0.7149,  -0.9490]])
#
# Snapshot 7 in game 7f71f4d8-167c-40d7-81ae-bb88e718e87e:
# Real action: {'type': 'state', 'state_idx': 2, 'state': 'take'}
# Predicted action: {'type': 'state', 'state': 'take'}
# Action type: CORRECT
# State: CORRECT
# action_logits: tensor([[ -17.9742, -211.3536,   -8.5746,    5.0631]])
#
# Snapshot 8 in game 7f71f4d8-167c-40d7-81ae-bb88e718e87e:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -17.9742, -211.3536,   -8.5746,    5.0631]])
#
# Snapshot 9 in game 7f71f4d8-167c-40d7-81ae-bb88e718e87e:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -19.3734, -170.7145,  -16.7602,    3.6437]])
#
# Snapshot 10 in game 7f71f4d8-167c-40d7-81ae-bb88e718e87e:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -0.7016, -60.3582,  -5.7827,   0.9778]])
#
# Snapshot 11 in game 7f71f4d8-167c-40d7-81ae-bb88e718e87e:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -29.2364, -271.6794,  -27.2775,    7.2122]])
#
# Snapshot 12 in game 7f71f4d8-167c-40d7-81ae-bb88e718e87e:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -9.2660, -98.3981,  -7.1534,   1.8610]])
#
# Snapshot 13 in game 7f71f4d8-167c-40d7-81ae-bb88e718e87e:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -15.3066, -133.0909,  -12.5437,    3.1671]])
#
# Snapshot 14 in game 7f71f4d8-167c-40d7-81ae-bb88e718e87e:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# State change detected: defend -> take
# action_logits: tensor([[ -6.3642, -58.5954,  -0.8897,  -0.7164]])
#
# Snapshot 15 in game 7f71f4d8-167c-40d7-81ae-bb88e718e87e:
# Real action: {'type': 'state', 'state_idx': 2, 'state': 'take'}
# Predicted action: {'type': 'wait'}
# Action type: WRONG (Real: state, Predicted: wait)
# action_logits: tensor([[ -51.6472, -465.1353,  -37.1005,   11.7653]])
#
# Snapshot 16 in game 7f71f4d8-167c-40d7-81ae-bb88e718e87e:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -51.6472, -465.1353,  -37.1005,   11.7653]])
#
# Snapshot 17 in game 7f71f4d8-167c-40d7-81ae-bb88e718e87e:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -22.1816, -210.5778,  -20.2083,    4.0306]])
#
# Snapshot 18 in game 7f71f4d8-167c-40d7-81ae-bb88e718e87e:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# Detected transfer: 10S matches 10C
# action_logits: tensor([[  3.8984, -62.3324,  -6.9756,   0.4202]])
#
# Snapshot 19 in game 7f71f4d8-167c-40d7-81ae-bb88e718e87e:
# Real action: {'type': 'attack', 'card_idx': 4, 'card': '10S'}
# ...
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# State change detected: attack -> pass
# action_logits: tensor([[ -1.8015, -67.7151,  -1.4335,   1.4588]])
#
# Snapshot 16 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'state', 'state_idx': 1, 'state': 'pass'}
# Predicted action: {'type': 'wait'}
# Action type: WRONG (Real: state, Predicted: wait)
# action_logits: tensor([[ -45.8214, -614.9627,  -38.0361,   15.6760]])
#
# Snapshot 17 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[  5.8232, -87.8549,  -9.7771,  -3.2033]])
#
# Snapshot 18 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'attack', 'card_idx': 3, 'card': '9H'}
# Predicted action: {'type': 'attack', 'move': '9H'}
# Action type: CORRECT
# Card: CORRECT
# action_logits: tensor([[ -0.4537, -97.4577,  -7.0115,   4.9973]])
#
# Snapshot 19 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[  0.7189, -63.1059,  -5.1850,   2.2874]])
#
# Snapshot 20 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -13.2151, -159.2808,   -9.9261,    2.8614]])
#
# Snapshot 21 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -31.6381, -346.1694,  -29.8644,    6.4337]])
#
# Snapshot 22 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -31.6381, -346.1694,  -29.8644,    6.4337]])
#
# Snapshot 23 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[  8.5248, -82.1983, -10.5795, -16.0598]])
#
# Snapshot 24 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'attack', 'card_idx': 12, 'card': '12S'}
# Predicted action: {'type': 'attack', 'move': '13S'}
# Action type: CORRECT
# Card: WRONG (Real: 12S, Predicted: 13S)
# action_logits: tensor([[ -2.7321, -37.4590,  -0.3518,   0.8875]])
#
# Snapshot 25 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# State change detected: attack -> pass
# action_logits: tensor([[ -2.7321, -37.4590,  -0.3518,   0.8875]])
#
# Snapshot 26 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'state', 'state_idx': 1, 'state': 'pass'}
# Predicted action: {'type': 'wait'}
# Action type: WRONG (Real: state, Predicted: wait)
# action_logits: tensor([[ -92.1176, -903.2142,  -69.1535,   20.1261]])
#
# Snapshot 27 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[  6.9254, -90.9951, -12.1161, -15.6295]])
#
# Snapshot 28 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'attack', 'card_idx': 16, 'card': '13S'}
# Predicted action: {'type': 'attack', 'move': '13S'}
# Action type: CORRECT
# Card: CORRECT
# action_logits: tensor([[ -1.7472, -29.8041,  -0.4909,   0.9033]])
#
# Snapshot 29 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# State change detected: attack -> pass
# action_logits: tensor([[ -1.7472, -29.8041,  -0.4909,   0.9033]])
#
# Snapshot 30 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'state', 'state_idx': 1, 'state': 'pass'}
# Predicted action: {'type': 'wait'}
# Action type: WRONG (Real: state, Predicted: wait)
# action_logits: tensor([[ -93.3130, -881.6633,  -66.4034,   19.1201]])
#
# Snapshot 31 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[  5.7769, -66.7265,  -5.8569, -14.2728]])
#
# Snapshot 32 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'attack', 'card_idx': 9, 'card': '11C'}
# Predicted action: {'type': 'attack', 'move': '13S'}
# Action type: CORRECT
# Card: WRONG (Real: 11C, Predicted: 13S)
# action_logits: tensor([[  0.1053, -22.0309,  -1.0016,   0.6911]])
#
# Snapshot 33 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# State change detected: attack -> pass
# action_logits: tensor([[  0.1053, -22.0309,  -1.0016,   0.6911]])
#
# Snapshot 34 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'state', 'state_idx': 1, 'state': 'pass'}
# Predicted action: {'type': 'wait'}
# Action type: WRONG (Real: state, Predicted: wait)
# action_logits: tensor([[ -73.1811, -768.3620,  -61.1597,   16.6097]])
#
# Snapshot 35 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[   6.8042, -118.4280,  -16.1169,  -15.5137]])
#
# Snapshot 36 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'attack', 'card_idx': 7, 'card': '10H'}
# Predicted action: {'type': 'attack', 'move': '13C'}
# Action type: CORRECT
# Card: WRONG (Real: 10H, Predicted: 13C)
# action_logits: tensor([[ -0.6380, -46.3684,  -3.0943,   2.1306]])
#
# Snapshot 37 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# State change detected: defend -> take
# action_logits: tensor([[ -9.9570, -65.2827,  -1.2814,   0.6232]])
#
# Snapshot 38 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'state', 'state_idx': 2, 'state': 'take'}
# Predicted action: {'type': 'wait'}
# Action type: WRONG (Real: state, Predicted: wait)
# action_logits: tensor([[ -49.1794, -516.9758,  -30.1335,   10.9550]])
#
# Snapshot 39 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -49.1794, -516.9758,  -30.1335,   10.9550]])
#
# Snapshot 40 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -44.3209, -409.6590,  -39.4462,   11.6841]])
#
# Snapshot 41 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# State change detected: defend -> take
# action_logits: tensor([[-12.5965, -84.7504,  -1.7904,   0.8366]])
#
# Snapshot 42 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'state', 'state_idx': 2, 'state': 'take'}
# Predicted action: {'type': 'wait'}
# Action type: WRONG (Real: state, Predicted: wait)
# action_logits: tensor([[ -75.4053, -746.3234,  -62.7469,   14.9816]])
#
# Snapshot 43 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -75.4053, -746.3234,  -62.7469,   14.9816]])
#
# Snapshot 44 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -44.9527, -422.6677,  -40.6605,   11.9731]])
#
# Snapshot 45 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# State change detected: defend -> take
# action_logits: tensor([[ -19.2535, -120.9729,   -2.3174,    0.9266]])
#
# Snapshot 46 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'state', 'state_idx': 2, 'state': 'take'}
# Predicted action: {'type': 'wait'}
# Action type: WRONG (Real: state, Predicted: wait)
# action_logits: tensor([[ -78.4780, -748.6320,  -61.7051,   14.8231]])
#
# Snapshot 47 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -78.4780, -748.6320,  -61.7051,   14.8231]])
#
# Snapshot 48 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -45.7184, -440.4330,  -42.3246,   11.6535]])
#
# Snapshot 49 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# State change detected: defend -> take
# action_logits: tensor([[ -11.9757, -104.0833,   -4.4687,    1.6185]])
#
# Snapshot 50 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'state', 'state_idx': 2, 'state': 'take'}
# Predicted action: {'type': 'wait'}
# Action type: WRONG (Real: state, Predicted: wait)
# action_logits: tensor([[ -53.3066, -575.9706,  -47.4280,   10.5660]])
#
# Snapshot 51 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -53.3066, -575.9706,  -47.4280,   10.5660]])
#
# Snapshot 52 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -44.7014, -450.4613,  -44.2459,   11.0035]])
#
# Snapshot 53 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -11.6565, -181.4173,  -13.0016,    2.7358]])
#
# Snapshot 54 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -46.5401, -456.2032,  -39.6301,    9.6020]])
#
# Snapshot 55 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -46.5401, -456.2032,  -39.6301,    9.6020]])
#
# Snapshot 56 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[  10.5043, -233.4093,  -33.8328,  -19.7340]])
#
# Snapshot 57 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'attack', 'card_idx': 5, 'card': '10C'}
# Predicted action: {'type': 'attack', 'move': '10C'}
# Action type: CORRECT
# Card: CORRECT
# action_logits: tensor([[   3.6232, -147.2082,  -13.7165,   -4.0846]])
#
# Snapshot 58 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'attack', 'move': '10H'}
# Action type: WRONG (Real: wait, Predicted: attack)
# Detected transfer: 10H matches 10C
# action_logits: tensor([[   4.4687, -199.4293,  -17.1003,  -20.1446]])
#
# Snapshot 59 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'attack', 'card_idx': 7, 'card': '10H'}
# Predicted action: {'type': 'attack', 'move': '10C'}
# Action type: CORRECT
# Card: WRONG (Real: 10H, Predicted: 10C)
# action_logits: tensor([[  -3.7044, -101.5706,   -4.4688,   -1.6194]])
#
# Snapshot 60 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[  -1.6581, -110.8832,   -0.4083,  -18.8198]])
#
# Snapshot 61 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'attack', 'card_idx': 8, 'card': '11S'}
# Predicted action: {'type': 'state', 'state': 'bat'}
# Action type: WRONG (Real: attack, Predicted: state)
# action_logits: tensor([[ -17.2931, -165.1167,   -1.5911,   -3.4784]])
#
# Snapshot 62 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'state', 'state': 'bat'}
# Action type: WRONG (Real: wait, Predicted: state)
# State change detected: attack -> bat
# action_logits: tensor([[ -16.9680, -185.1910,   -0.9296,  -12.1277]])
#
# Snapshot 63 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'state', 'state_idx': 0, 'state': 'bat'}
# Predicted action: {'type': 'state', 'state': 'bat'}
# Action type: CORRECT
# State: CORRECT
# action_logits: tensor([[ -154.5173, -1490.0336,  -119.8833,    36.5661]])
#
# Snapshot 64 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -38.1641, -333.7442,  -29.0464,    9.0473]])
#
# Snapshot 65 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -14.2071, -127.4431,   -5.9305,    1.1891]])
#
# Snapshot 66 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -45.9167, -456.3847,  -37.0421,   10.8312]])
#
# Snapshot 67 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -19.5242, -170.5836,   -5.4926,    2.9515]])
#
# Snapshot 68 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[-11.4481, -69.7346,   0.5621,   1.0413]])
#
# Snapshot 69 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# State change detected: defend -> take
# action_logits: tensor([[ -8.6144, -55.3225,   0.8356,   0.2753]])
#
# Snapshot 70 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'state', 'state_idx': 2, 'state': 'take'}
# Predicted action: {'type': 'state', 'state': 'take'}
# Action type: CORRECT
# State: CORRECT
# action_logits: tensor([[ -79.3188, -764.3523,  -36.6351,   15.5305]])
#
# Snapshot 71 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -79.3188, -764.3523,  -36.6351,   15.5305]])
#
# Snapshot 72 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -43.1914, -415.3058,  -39.7433,   10.0969]])
#
# Snapshot 73 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -18.1996, -200.7331,  -12.0246,    3.4810]])
#
# Snapshot 74 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[  -7.3783, -130.5882,   -7.6856,    3.7081]])
#
# Snapshot 75 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -10.7054, -171.2048,   -9.7982,    4.0881]])
#
# Snapshot 76 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -20.0456, -235.7545,  -16.7322,    5.2697]])
#
# Snapshot 77 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[ -20.0456, -235.7545,  -16.7322,    5.2697]])
#
# Snapshot 78 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
# action_logits: tensor([[  9.1298, -88.3266, -15.1494, -14.2033]])
#
# Snapshot 79 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'attack', 'card_idx': 2, 'card': '9D'}
# Predicted action: {'type': 'attack', 'move': '13S'}
# Action type: CORRECT
# Card: WRONG (Real: 9D, Predicted: 13S)
# action_logits: tensor([[ -0.2142, -61.6972,  -4.1758,   1.7020]])
#
# Snapshot 80 in game 80cffe94-ac74-4f7f-9a7f-ae41eb6f6803:
# Real action: {'type': 'wait'}
# Predicted action: {'type': 'wait'}
# Action type: CORRECT
#
# === Testing Summary ===
# Total samples tested: 577
# Invalid samples skipped: 0
# Action type accuracy: 88.56% (511/577)
