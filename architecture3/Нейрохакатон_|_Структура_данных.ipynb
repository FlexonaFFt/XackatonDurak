# %%
# !pip install datasets
from datasets import load_dataset
dataset = load_dataset("neuronetties/durak")
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (3.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.12.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets) (2024.12.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.15)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.30.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.3.2)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)

# %% [markdown]
# # Формат датасета
#
# Датасет представляет из себя массив строк последовательных снапшотов. У каждой записи есть `game_id` - идентификатор игры и `snapshot` - снимок состояния игры представленный в виде JSON. У каждой игры есть несколько снапшотов (если `game_id` одинаковый, значит снапшоты принадлежат одной игре). Каждый снапшот имеет в себе значение `timestamp` - порядковый номер снапшота внутри.

# %%
# Выведем все снашоты относящиеся к одной из игр по ID.

game_id_to_find = "8219abbc-7ec9-48f5-b9be-63374c227d6d"
filtered_dataset = dataset.filter(lambda example: example['game_id'] == game_id_to_find)

for snapshot in filtered_dataset['train']:
  print(snapshot)
# Out:
# {'game_id': '8219abbc-7ec9-48f5-b9be-63374c227d6d', 'snapshot': '{"game_id": "8219abbc-7ec9-48f5-b9be-63374c227d6d", "trump": "14S", "timestamp": 0, "winner": "7399412313", "game_rules": {"game_type": 1, "player_amount": 2, "card_amount": 24}, "deck": ["14S", "13D", "9C", "14H", "11S", "11C", "10C", "12H", "9D", "11H", "12S", "9H"], "bat": [], "table": [], "players": [{"id": "7399412313", "state": "attack", "hand": ["10D", "12D", "13C", "14C", "9S", "13S"]}, {"id": "224737994", "state": "defend", "hand": ["11D", "14D", "12C", "10H", "13H", "10S"]}]}'}
# {'game_id': '8219abbc-7ec9-48f5-b9be-63374c227d6d', 'snapshot': '{"game_id": "8219abbc-7ec9-48f5-b9be-63374c227d6d", "trump": "14S", "timestamp": 1, "winner": "7399412313", "game_rules": {"game_type": 1, "player_amount": 2, "card_amount": 24}, "deck": ["14S", "13D", "9C", "14H", "11S", "11C", "10C", "12H", "9D", "11H", "12S", "9H"], "bat": [], "table": [{"attack_card": {"card": "10D", "user_id": "7399412313"}}], "players": [{"id": "7399412313", "state": "attack", "hand": ["12D", "13C", "14C", "9S", "13S"]}, {"id": "224737994", "state": "defend", "hand": ["11D", "14D", "12C", "10H", "13H", "10S"]}]}'}
# {'game_id': '8219abbc-7ec9-48f5-b9be-63374c227d6d', 'snapshot': '{"game_id": "8219abbc-7ec9-48f5-b9be-63374c227d6d", "trump": "14S", "timestamp": 2, "winner": "7399412313", "game_rules": {"game_type": 1, "player_amount": 2, "card_amount": 24}, "deck": ["14S", "13D", "9C", "14H", "11S", "11C", "10C", "12H", "9D", "11H", "12S", "9H"], "bat": [], "table": [{"attack_card": {"card": "10D", "user_id": "7399412313"}, "defend_card": {"card": "11D", "user_id": "224737994"}}], "players": [{"id": "7399412313", "state": "attack", "hand": ["12D", "13C", "14C", "9S", "13S"]}, {"id": "224737994", "state": "defend", "hand": ["14D", "12C", "10H", "13H", "10S"]}]}'}
# {'game_id': '8219abbc-7ec9-48f5-b9be-63374c227d6d', 'snapshot': '{"game_id": "8219abbc-7ec9-48f5-b9be-63374c227d6d", "trump": "14S", "timestamp": 34, "winner": "7399412313", "game_rules": {"game_type": 1, "player_amount": 2, "card_amount": 24}, "deck": [], "bat": ["10D", "11D", "10H", "9S", "9D", "14D", "14C", "10S", "11C", "13C", "11H", "12H", "13H", "13S", "9H", "14H", "9C", "10C"], "table": [], "players": [{"id": "7399412313", "state": "attack", "hand": ["12D"]}, {"id": "224737994", "state": "defend", "hand": ["13D", "12C", "11S", "12S", "14S"]}]}'}
# {'game_id': '8219abbc-7ec9-48f5-b9be-63374c227d6d', 'snapshot': '{"game_id": "8219abbc-7ec9-48f5-b9be-63374c227d6d", "trump": "14S", "timestamp": 35, "winner": "7399412313", "game_rules": {"game_type": 1, "player_amount": 2, "card_amount": 24}, "deck": [], "bat": ["10D", "11D", "10H", "9S", "9D", "14D", "14C", "10S", "11C", "13C", "11H", "12H", "13H", "13S", "9H", "14H", "9C", "10C"], "table": [{"attack_card": {"card": "12D", "user_id": "7399412313"}}], "players": [{"id": "7399412313", "state": "winner", "hand": []}, {"id": "224737994", "state": "durak", "hand": ["13D", "12C", "11S", "12S", "14S"]}]}'}

# %%
# Переведем JSON снапшоты в человеческий язык.

import json

# Получаем первый снапшот
first_snapshot_data = json.loads(filtered_dataset['train'][0]['snapshot'])

# Общая информация об игре (смотрим по первому снапшоту, т.е. общая информация во всех снапшотах с одинаковым game_id - одинаковая)
print("=== Общая информация об игре ===")
print(f"ID игры: {first_snapshot_data['game_id']}")
print(f"Режим: {'Классический' if first_snapshot_data['game_rules']['game_type'] == 0 else 'Переводной'}")
print(f"Козырь: {first_snapshot_data['trump']}")
print(f"Количество игроков: {first_snapshot_data['game_rules']['player_amount']}")
print(f"Количество карт в колоде: {first_snapshot_data['game_rules']['card_amount']}")
print(f"Победитель: {first_snapshot_data['winner']}")
print()

# Состояния по каждому снапшоту
print("=== Ход игры по снапшотам ===")
for snap in filtered_dataset['train']:
    data = json.loads(snap['snapshot'])
    print(f"\n--- Снапшот t={data['timestamp']} ---")

    # Игроки и их карты
    for player in data['players']:
        role = {
            "attack": "Атакует",
            "defend": "Обороняется",
            "bat": "Ход окончен (бито)",
            "take": "Берёт карты",
            "pass": "Пропускает",
            "winner": "Победил",
            "durak": "Проиграл",
        }.get(player["state"], player["state"])
        print(f"Игрок {player['id']} — {role}")
        print(f"  Карты на руке: {', '.join(player['hand']) if player['hand'] else 'Нет карт'}")

    # Карты на столе
    if data["table"]:
        print("На столе:")
        for pair in data["table"]:
            attack = pair['attack_card']['card']
            attacker = pair['attack_card']['user_id']
            defend = pair.get('defend_card')
            if defend:
                defend_card = defend['card']
                defender = defend['user_id']
                print(f"  {attacker} атакует {attack}, {defender} отбивается {defend_card}")
            else:
                print(f"  {attacker} атакует {attack}, защита ещё не сыграна")
    else:
        print("На столе: пусто")

    # Колода
    print(f"Колода: {len(data['deck'])} карт" + (f" ({', '.join(data['deck'])})" if data['deck'] else ""))

    # Бито
    print(f"Бито: {len(data['bat'])} карт" + (f" ({', '.join(data['bat'])})" if data['bat'] else ""))
# Out:
# === Общая информация об игре ===
# ID игры: 8219abbc-7ec9-48f5-b9be-63374c227d6d
# Режим: Переводной
# Козырь: 14S
# Количество игроков: 2
# Количество карт в колоде: 24
# Победитель: 7399412313
#
# === Ход игры по снапшотам ===
#
# --- Снапшот t=0 ---
# Игрок 7399412313 — Атакует
#   Карты на руке: 10D, 12D, 13C, 14C, 9S, 13S
# Игрок 224737994 — Обороняется
#   Карты на руке: 11D, 14D, 12C, 10H, 13H, 10S
# На столе: пусто
# Колода: 12 карт (14S, 13D, 9C, 14H, 11S, 11C, 10C, 12H, 9D, 11H, 12S, 9H)
# Бито: 0 карт
#
# --- Снапшот t=1 ---
# Игрок 7399412313 — Атакует
#   Карты на руке: 12D, 13C, 14C, 9S, 13S
# Игрок 224737994 — Обороняется
#   Карты на руке: 11D, 14D, 12C, 10H, 13H, 10S
# На столе:
#   7399412313 атакует 10D, защита ещё не сыграна
# Колода: 12 карт (14S, 13D, 9C, 14H, 11S, 11C, 10C, 12H, 9D, 11H, 12S, 9H)
# Бито: 0 карт
#
# --- Снапшот t=2 ---
# Игрок 7399412313 — Атакует
#   Карты на руке: 12D, 13C, 14C, 9S, 13S
# Игрок 224737994 — Обороняется
#   Карты на руке: 14D, 12C, 10H, 13H, 10S
# На столе:
#   7399412313 атакует 10D, 224737994 отбивается 11D
# Колода: 12 карт (14S, 13D, 9C, 14H, 11S, 11C, 10C, 12H, 9D, 11H, 12S, 9H)
# Бито: 0 карт
#
# --- Снапшот t=3 ---
# Игрок 7399412313 — Ход окончен (бито)
#   Карты на руке: 12D, 13C, 14C, 9S, 13S
# Игрок 224737994 — Обороняется
#   Карты на руке: 14D, 12C, 10H, 13H, 10S
# На столе:
#   7399412313 атакует 10D, 224737994 отбивается 11D
# Колода: 12 карт (14S, 13D, 9C, 14H, 11S, 11C, 10C, 12H, 9D, 11H, 12S, 9H)
# Бито: 0 карт
#
# --- Снапшот t=4 ---
# Игрок 7399412313 — Обороняется
#   Карты на руке: 12D, 13C, 14C, 9H, 9S, 13S
# Игрок 224737994 — Атакует
#   Карты на руке: 14D, 12C, 10H, 13H, 10S, 12S
# На столе: пусто
# Колода: 10 карт (14S, 13D, 9C, 14H, 11S, 11C, 10C, 12H, 9D, 11H)
# Бито: 2 карт (10D, 11D)
#
# --- Снапшот t=5 ---
# Игрок 7399412313 — Обороняется
#   Карты на руке: 12D, 13C, 14C, 9H, 9S, 13S
# Игрок 224737994 — Атакует
#   Карты на руке: 14D, 12C, 13H, 10S, 12S
# На столе:
#   224737994 атакует 10H, защита ещё не сыграна
# Колода: 10 карт (14S, 13D, 9C, 14H, 11S, 11C, 10C, 12H, 9D, 11H)
# Бито: 2 карт (10D, 11D)
#
# --- Снапшот t=6 ---
# Игрок 7399412313 — Обороняется
#   Карты на руке: 12D, 13C, 14C, 9H, 13S
# Игрок 224737994 — Атакует
#   Карты на руке: 14D, 12C, 13H, 10S, 12S
# На столе:
#   224737994 атакует 10H, 7399412313 отбивается 9S
# Колода: 10 карт (14S, 13D, 9C, 14H, 11S, 11C, 10C, 12H, 9D, 11H)
# Бито: 2 карт (10D, 11D)
#
# --- Снапшот t=7 ---
# Игрок 7399412313 — Обороняется
#   Карты на руке: 12D, 13C, 14C, 9H, 13S
# Игрок 224737994 — Ход окончен (бито)
#   Карты на руке: 14D, 12C, 13H, 10S, 12S
# На столе:
#   224737994 атакует 10H, 7399412313 отбивается 9S
# Колода: 10 карт (14S, 13D, 9C, 14H, 11S, 11C, 10C, 12H, 9D, 11H)
# Бито: 2 карт (10D, 11D)
#
# --- Снапшот t=8 ---
# Игрок 7399412313 — Атакует
#   Карты на руке: 9D, 12D, 13C, 14C, 9H, 13S
# Игрок 224737994 — Обороняется
#   Карты на руке: 14D, 12C, 11H, 13H, 10S, 12S
# На столе: пусто
# Колода: 8 карт (14S, 13D, 9C, 14H, 11S, 11C, 10C, 12H)
# Бито: 4 карт (10D, 11D, 10H, 9S)
#
# --- Снапшот t=9 ---
# Игрок 7399412313 — Атакует
#   Карты на руке: 12D, 13C, 14C, 9H, 13S
# Игрок 224737994 — Обороняется
#   Карты на руке: 14D, 12C, 11H, 13H, 10S, 12S
# На столе:
#   7399412313 атакует 9D, защита ещё не сыграна
# Колода: 8 карт (14S, 13D, 9C, 14H, 11S, 11C, 10C, 12H)
# Бито: 4 карт (10D, 11D, 10H, 9S)
#
# --- Снапшот t=10 ---
# Игрок 7399412313 — Атакует
#   Карты на руке: 12D, 13C, 14C, 9H, 13S
# Игрок 224737994 — Обороняется
#   Карты на руке: 12C, 11H, 13H, 10S, 12S
# На столе:
#   7399412313 атакует 9D, 224737994 отбивается 14D
# Колода: 8 карт (14S, 13D, 9C, 14H, 11S, 11C, 10C, 12H)
# Бито: 4 карт (10D, 11D, 10H, 9S)
#
# --- Снапшот t=11 ---
# Игрок 7399412313 — Атакует
#   Карты на руке: 12D, 13C, 9H, 13S
# Игрок 224737994 — Обороняется
#   Карты на руке: 12C, 11H, 13H, 10S, 12S
# На столе:
#   7399412313 атакует 9D, 224737994 отбивается 14D
#   7399412313 атакует 14C, защита ещё не сыграна
# Колода: 8 карт (14S, 13D, 9C, 14H, 11S, 11C, 10C, 12H)
# Бито: 4 карт (10D, 11D, 10H, 9S)
#
# --- Снапшот t=12 ---
# Игрок 7399412313 — Атакует
#   Карты на руке: 12D, 13C, 9H, 13S
# Игрок 224737994 — Обороняется
#   Карты на руке: 12C, 11H, 13H, 12S
# На столе:
#   7399412313 атакует 9D, 224737994 отбивается 14D
#   7399412313 атакует 14C, 224737994 отбивается 10S
# Колода: 8 карт (14S, 13D, 9C, 14H, 11S, 11C, 10C, 12H)
# Бито: 4 карт (10D, 11D, 10H, 9S)
#
# --- Снапшот t=13 ---
# Игрок 7399412313 — Ход окончен (бито)
#   Карты на руке: 12D, 13C, 9H, 13S
# Игрок 224737994 — Обороняется
#   Карты на руке: 12C, 11H, 13H, 12S
# На столе:
#   7399412313 атакует 9D, 224737994 отбивается 14D
#   7399412313 атакует 14C, 224737994 отбивается 10S
# Колода: 8 карт (14S, 13D, 9C, 14H, 11S, 11C, 10C, 12H)
# Бито: 4 карт (10D, 11D, 10H, 9S)
#
# --- Снапшот t=14 ---
# Игрок 7399412313 — Обороняется
#   Карты на руке: 12D, 10C, 13C, 9H, 12H, 13S
# Игрок 224737994 — Атакует
#   Карты на руке: 11C, 12C, 11H, 13H, 11S, 12S
# На столе: пусто
# Колода: 4 карт (14S, 13D, 9C, 14H)
# Бито: 8 карт (10D, 11D, 10H, 9S, 9D, 14D, 14C, 10S)
#
# --- Снапшот t=15 ---
# Игрок 7399412313 — Обороняется
#   Карты на руке: 12D, 10C, 13C, 9H, 12H, 13S
# Игрок 224737994 — Атакует
#   Карты на руке: 12C, 11H, 13H, 11S, 12S
# На столе:
#   224737994 атакует 11C, защита ещё не сыграна
# Колода: 4 карт (14S, 13D, 9C, 14H)
# Бито: 8 карт (10D, 11D, 10H, 9S, 9D, 14D, 14C, 10S)
#
# --- Снапшот t=16 ---
# Игрок 7399412313 — Обороняется
#   Карты на руке: 12D, 10C, 13C, 9H, 12H, 13S
# Игрок 224737994 — Атакует
#   Карты на руке: 12C, 13H, 11S, 12S
# На столе:
#   224737994 атакует 11C, защита ещё не сыграна
#   224737994 атакует 11H, защита ещё не сыграна
# Колода: 4 карт (14S, 13D, 9C, 14H)
# Бито: 8 карт (10D, 11D, 10H, 9S, 9D, 14D, 14C, 10S)
#
# --- Снапшот t=17 ---
# Игрок 7399412313 — Обороняется
#   Карты на руке: 12D, 10C, 9H, 12H, 13S
# Игрок 224737994 — Атакует
#   Карты на руке: 12C, 13H, 11S, 12S
# На столе:
#   224737994 атакует 11C, 7399412313 отбивается 13C
#   224737994 атакует 11H, защита ещё не сыграна
# Колода: 4 карт (14S, 13D, 9C, 14H)
# Бито: 8 карт (10D, 11D, 10H, 9S, 9D, 14D, 14C, 10S)
#
# --- Снапшот t=18 ---
# Игрок 7399412313 — Обороняется
#   Карты на руке: 12D, 10C, 9H, 13S
# Игрок 224737994 — Атакует
#   Карты на руке: 12C, 13H, 11S, 12S
# На столе:
#   224737994 атакует 11C, 7399412313 отбивается 13C
#   224737994 атакует 11H, 7399412313 отбивается 12H
# Колода: 4 карт (14S, 13D, 9C, 14H)
# Бито: 8 карт (10D, 11D, 10H, 9S, 9D, 14D, 14C, 10S)
#
# --- Снапшот t=19 ---
# Игрок 7399412313 — Обороняется
#   Карты на руке: 12D, 10C, 9H, 13S
# Игрок 224737994 — Атакует
#   Карты на руке: 12C, 11S, 12S
# На столе:
#   224737994 атакует 11C, 7399412313 отбивается 13C
#   224737994 атакует 11H, 7399412313 отбивается 12H
#   224737994 атакует 13H, защита ещё не сыграна
# Колода: 4 карт (14S, 13D, 9C, 14H)
# Бито: 8 карт (10D, 11D, 10H, 9S, 9D, 14D, 14C, 10S)
#
# --- Снапшот t=20 ---
# Игрок 7399412313 — Обороняется
#   Карты на руке: 12D, 10C, 9H
# Игрок 224737994 — Атакует
#   Карты на руке: 12C, 11S, 12S
# На столе:
#   224737994 атакует 11C, 7399412313 отбивается 13C
#   224737994 атакует 11H, 7399412313 отбивается 12H
#   224737994 атакует 13H, 7399412313 отбивается 13S
# Колода: 4 карт (14S, 13D, 9C, 14H)
# Бито: 8 карт (10D, 11D, 10H, 9S, 9D, 14D, 14C, 10S)
#
# --- Снапшот t=21 ---
# Игрок 7399412313 — Обороняется
#   Карты на руке: 12D, 10C, 9H
# Игрок 224737994 — Ход окончен (бито)
#   Карты на руке: 12C, 11S, 12S
# На столе:
#   224737994 атакует 11C, 7399412313 отбивается 13C
#   224737994 атакует 11H, 7399412313 отбивается 12H
#   224737994 атакует 13H, 7399412313 отбивается 13S
# Колода: 4 карт (14S, 13D, 9C, 14H)
# Бито: 8 карт (10D, 11D, 10H, 9S, 9D, 14D, 14C, 10S)
#
# --- Снапшот t=22 ---
# Игрок 7399412313 — Атакует
#   Карты на руке: 12D, 10C, 9H, 14S
# Игрок 224737994 — Обороняется
#   Карты на руке: 13D, 9C, 12C, 14H, 11S, 12S
# На столе: пусто
# Колода: 0 карт
# Бито: 14 карт (10D, 11D, 10H, 9S, 9D, 14D, 14C, 10S, 11C, 13C, 11H, 12H, 13H, 13S)
#
# --- Снапшот t=23 ---
# Игрок 7399412313 — Атакует
#   Карты на руке: 12D, 10C, 14S
# Игрок 224737994 — Обороняется
#   Карты на руке: 13D, 9C, 12C, 14H, 11S, 12S
# На столе:
#   7399412313 атакует 9H, защита ещё не сыграна
# Колода: 0 карт
# Бито: 14 карт (10D, 11D, 10H, 9S, 9D, 14D, 14C, 10S, 11C, 13C, 11H, 12H, 13H, 13S)
#
# --- Снапшот t=24 ---
# Игрок 7399412313 — Атакует
#   Карты на руке: 12D, 10C, 14S
# Игрок 224737994 — Обороняется
#   Карты на руке: 13D, 9C, 12C, 11S, 12S
# На столе:
#   7399412313 атакует 9H, 224737994 отбивается 14H
# Колода: 0 карт
# Бито: 14 карт (10D, 11D, 10H, 9S, 9D, 14D, 14C, 10S, 11C, 13C, 11H, 12H, 13H, 13S)
#
# --- Снапшот t=25 ---
# Игрок 7399412313 — Ход окончен (бито)
#   Карты на руке: 12D, 10C, 14S
# Игрок 224737994 — Обороняется
#   Карты на руке: 13D, 9C, 12C, 11S, 12S
# На столе:
#   7399412313 атакует 9H, 224737994 отбивается 14H
# Колода: 0 карт
# Бито: 14 карт (10D, 11D, 10H, 9S, 9D, 14D, 14C, 10S, 11C, 13C, 11H, 12H, 13H, 13S)
#
# --- Снапшот t=26 ---
# Игрок 7399412313 — Обороняется
#   Карты на руке: 12D, 10C, 14S
# Игрок 224737994 — Атакует
#   Карты на руке: 13D, 9C, 12C, 11S, 12S
# На столе: пусто
# Колода: 0 карт
# Бито: 16 карт (10D, 11D, 10H, 9S, 9D, 14D, 14C, 10S, 11C, 13C, 11H, 12H, 13H, 13S, 9H, 14H)
#
# --- Снапшот t=27 ---
# Игрок 7399412313 — Обороняется
#   Карты на руке: 12D, 10C, 14S
# Игрок 224737994 — Атакует
#   Карты на руке: 13D, 12C, 11S, 12S
# На столе:
#   224737994 атакует 9C, защита ещё не сыграна
# Колода: 0 карт
# Бито: 16 карт (10D, 11D, 10H, 9S, 9D, 14D, 14C, 10S, 11C, 13C, 11H, 12H, 13H, 13S, 9H, 14H)
#
# --- Снапшот t=28 ---
# Игрок 7399412313 — Обороняется
#   Карты на руке: 12D, 14S
# Игрок 224737994 — Атакует
#   Карты на руке: 13D, 12C, 11S, 12S
# На столе:
#   224737994 атакует 9C, 7399412313 отбивается 10C
# Колода: 0 карт
# Бито: 16 карт (10D, 11D, 10H, 9S, 9D, 14D, 14C, 10S, 11C, 13C, 11H, 12H, 13H, 13S, 9H, 14H)
#
# --- Снапшот t=29 ---
# Игрок 7399412313 — Обороняется
#   Карты на руке: 12D, 14S
# Игрок 224737994 — Ход окончен (бито)
#   Карты на руке: 13D, 12C, 11S, 12S
# На столе:
#   224737994 атакует 9C, 7399412313 отбивается 10C
# Колода: 0 карт
# Бито: 16 карт (10D, 11D, 10H, 9S, 9D, 14D, 14C, 10S, 11C, 13C, 11H, 12H, 13H, 13S, 9H, 14H)
#
# --- Снапшот t=30 ---
# Игрок 7399412313 — Атакует
#   Карты на руке: 12D, 14S
# Игрок 224737994 — Обороняется
#   Карты на руке: 13D, 12C, 11S, 12S
# На столе: пусто
# Колода: 0 карт
# Бито: 18 карт (10D, 11D, 10H, 9S, 9D, 14D, 14C, 10S, 11C, 13C, 11H, 12H, 13H, 13S, 9H, 14H, 9C, 10C)
#
# --- Снапшот t=31 ---
# Игрок 7399412313 — Атакует
#   Карты на руке: 12D
# Игрок 224737994 — Обороняется
#   Карты на руке: 13D, 12C, 11S, 12S
# На столе:
#   7399412313 атакует 14S, защита ещё не сыграна
# Колода: 0 карт
# Бито: 18 карт (10D, 11D, 10H, 9S, 9D, 14D, 14C, 10S, 11C, 13C, 11H, 12H, 13H, 13S, 9H, 14H, 9C, 10C)
#
# --- Снапшот t=32 ---
# Игрок 7399412313 — Атакует
#   Карты на руке: 12D
# Игрок 224737994 — Берёт карты
#   Карты на руке: 13D, 12C, 11S, 12S
# На столе:
#   7399412313 атакует 14S, защита ещё не сыграна
# Колода: 0 карт
# Бито: 18 карт (10D, 11D, 10H, 9S, 9D, 14D, 14C, 10S, 11C, 13C, 11H, 12H, 13H, 13S, 9H, 14H, 9C, 10C)
#
# --- Снапшот t=33 ---
# Игрок 7399412313 — Пропускает
#   Карты на руке: 12D
# Игрок 224737994 — Берёт карты
#   Карты на руке: 13D, 12C, 11S, 12S
# На столе:
#   7399412313 атакует 14S, защита ещё не сыграна
# Колода: 0 карт
# Бито: 18 карт (10D, 11D, 10H, 9S, 9D, 14D, 14C, 10S, 11C, 13C, 11H, 12H, 13H, 13S, 9H, 14H, 9C, 10C)
#
# --- Снапшот t=34 ---
# Игрок 7399412313 — Атакует
#   Карты на руке: 12D
# Игрок 224737994 — Обороняется
#   Карты на руке: 13D, 12C, 11S, 12S, 14S
# На столе: пусто
# Колода: 0 карт
# Бито: 18 карт (10D, 11D, 10H, 9S, 9D, 14D, 14C, 10S, 11C, 13C, 11H, 12H, 13H, 13S, 9H, 14H, 9C, 10C)
#
# --- Снапшот t=35 ---
# Игрок 7399412313 — Победил
#   Карты на руке: Нет карт
# Игрок 224737994 — Проиграл
#   Карты на руке: 13D, 12C, 11S, 12S, 14S
# На столе:
#   7399412313 атакует 12D, защита ещё не сыграна
# Колода: 0 карт
# Бито: 18 карт (10D, 11D, 10H, 9S, 9D, 14D, 14C, 10S, 11C, 13C, 11H, 12H, 13H, 13S, 9H, 14H, 9C, 10C)

# %% [markdown]
# # Формат данных для отправки на сервер (доступные метода)

# %% [markdown]
# Структуры пакетов, отправляемых на сервер - вам не нужно это менять, просто показываем для понимания

# %%
# 1. Смена состояния (State)
state_pass = {"type": "state", "state": "pass"}
state_bat = {"type": "state", "state": "bat"}
state_take = {"type": "state", "state": "take"}

# 2. Атака или перевод (Attack)
# Пример: игрок атакует/переводит картой "10H"
attack_move = {"type": "attack", "move": "10H"}

# 3. Защита (Defend)
# Пример: защищаем "10H" картой "11H", и "9S" картой "12S"
defend_move = {
    "type": "defend",
    "move": [
        ["123123", "10H"],  # где "123123" — ID игрока, которые атакует, и карта "10H", которой атакуют
        ["321321", "11H"]   # где "321321" - ID игрока, который защищается (т.е. мы), и "11H" — карта, которой отбиваемся
    ]
}

# 4. Ожидание (Wait)
wait_packet = {"type": "wait"}

# %% [markdown]
# Пример клиента и методов, которые будут в нём. Его тоже менять не нужно, полноценный клиент появится **12.04**, когда мы откроем вам доступ к нему. Здесь вам важны только методы, которые вы можете вызвать.

# %%
class GameClient:
    def __init__(self):
        self.my_id = "example-id-123" # ID игрока (бота), за которого играем
        self.table = [
            {"attack_card": {"card": "10H", "user_id": "123"}},
            {"attack_card": {"card": "9S", "user_id": "123"}}
        ] # Стол. Он будет обновляться динамические сам, вам запариваться не надо

# --- --- --- Основные методы, которые может вызвать нейросеть, вам их менять не надо --- --- ---

    def send_pass(self):
        packet = {"type": "state", "state": "pass"}
        print(f"Отправлено действие: {packet}")

    def send_bat(self):
        packet = {"type": "state", "state": "bat"}
        print(f"Отправлено действие: {packet}")

    def send_take(self):
        packet = {"type": "state", "state": "take"}
        print(f"Отправлено действие: {packet}")

    def send_attack(self, card: str): # Атака и Перевод
        packet = {"type": "attack", "move": card}
        print(f"Отправлено действие: {packet}")

    def send_defend(self, attack_card: str, defend_card: str):
        attacker_id = None
        for pair in self.table:
            if pair.get("attack_card", {}).get("card") == attack_card:
                attacker_id = pair["attack_card"]["user_id"]
                break

        if not attacker_id:
            print(f"Ошибка: карта {attack_card} не найдена на столе.")
            return

        packet = {
            "type": "defend",
            "move": [
                [attacker_id, attack_card],
                [self.my_id, defend_card]
            ]
        }
        print(f"Отправлено действие: {packet}")

    def send_wait(self):
        packet = {"type": "wait"}
        print(f"Отправлено действие: {packet}")

# %%
client = GameClient()

client.send_pass()
client.send_bat()
client.send_take()
client.send_attack("14D")
client.send_defend("10H", "11H")
client.send_wait()
# Out:
# Отправлено действие: {'type': 'state', 'state': 'pass'}
# Отправлено действие: {'type': 'state', 'state': 'bat'}
# Отправлено действие: {'type': 'state', 'state': 'take'}
# Отправлено действие: {'type': 'attack', 'move': '14D'}
# Отправлено действие: {'type': 'defend', 'move': [['123', '10H'], ['example-id-123', '11H']]}
# Отправлено действие: {'type': 'wait'}
